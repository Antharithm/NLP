# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
load_dotenv()
# Out:
# True

# %%
# Read your api key environment variable

apiKey = os.getenv("NEWS_API_KEY")
type(apiKey)
# Out:
# str

# %%
# Create a newsapi client
from newsapi import NewsApiClient

newsapi = NewsApiClient(apiKey)

# %%
# Fetch the Bitcoin news articles

btc_all_articles = newsapi.get_everything(q='bitcoin',
                                    language='en',
                                    page_size=100,
                                    sort_by='relevancy')

btc_all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 7278,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Paul Ford',
#    'title': 'A Field Guide for Nature-Resistant Nerds',
#    'description': 'Yes, yes, the dirt is horrifying. But it’s also how we make bitcoin apps.',
#    'url': 'https://www.wired.com/story/a-field-guide-for-nature-resistant-nerds-microchips-climate-change/',
#    'urlToImage': 'https://media.wired.com/photos/61086c497b8c62be3062fe82/191:100/w_1280,c_limit/WI090121_MG_Ford_01.jpg',
#    'publishedAt': '2021-08-06T11:00:00Z',
#    'content': 'When my wife started a little garden in our urban backyard, all I could think about were the worms. Also the bugs, and the dirt, which is of course filled with worms and bugs and composted corn cobs.… [+3499 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Khari Johnson',
#    'title': 'Why Not Use Self-Driving Cars as Supercomputers?',
#    'description': 'Autonomous vehicles use the equivalent of 200 laptops to get around. Some want to tap that computing power to decode viruses or mine bitcoin.',
#    'url': 'https://www.wired.com/story/use-self-driving-cars-supercomputers/',
#    'urlToImage': 'https://media.wired.com/photos/60f081b4c147fe7a1a367362/191:100/w_1280,c_limit/Business-Autonomous-Vehicles-Supercomputers-1201885684.jpg',
#    'publishedAt': '2021-07-19T11:00:00Z',
#    'content': 'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Jack Dorsey says Bitcoin will unite the world, but doesn’t say how',
#    'description': 'Twitter and Square CEO Jack Dorsey claimed on Monday that the cryptocurrency can unite the world. “#Bitcoin will unite a deeply divided country. (and eventually: world),” he said. He hasn’t elaborated on how.',
#    'url': 'https://www.theverge.com/2021/8/9/22617551/jack-dorsey-bitcoin-unite-country-world-peace-cryptocurrency',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/HEyvuedlKAWanfGU9qYG1AUTBr8=/0x289:3000x1860/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22772533/1321753354.jpg',
#    'publishedAt': '2021-08-10T00:34:05Z',
#    'content': 'Photo by Joe Raedle/Getty Images\r\n\n \n\n Twitter and Square CEO Jack Dorsey, a noted superfan of Bitcoin, claimed on Monday that the cryptocurrency will eventually unite the world. Yes, really.\nOn Mond… [+2119 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'The fiendish new trick cyber-criminals are using to evade capture',
#    'description': 'Bitcoin researchers discover a new darknet tool criminals are using to help launder their digital money.',
#    'url': 'https://www.bbc.co.uk/news/technology-58176113',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/9B34/production/_119023793_127aa0f4-9a39-4be2-822b-cdc5d71f0a67.jpg',
#    'publishedAt': '2021-08-12T23:15:25Z',
#    'content': 'By Joe TidyCyber reporter \r\n"Follow the money" - for generations it\'s been the mantra of investigators looking for criminals.\r\nIn the cyber-realm, this battle between criminals and the authorities ha… [+3786 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Richard Dal Porto',
#    'title': 'Daily Crunch: Bitcoin ‘is a big part of our future,’ says Twitter CEO Jack Dorsey',
#    'description': 'Hello friends and welcome to Daily Crunch, bringing you the most important startup, tech and venture capital news in a single package.',
#    'url': 'http://techcrunch.com/2021/07/23/daily-crunch-bitcoin-is-a-big-part-of-our-future-says-twitter-ceo-jack-dorsey/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/10/GettyImages-1216921783.jpg?w=576',
#    'publishedAt': '2021-07-23T22:10:45Z',
#    'content': 'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox every day at 3 p.m. PDT, subscribe here.\r\nHello and welcome to Daily Crunch for July 23, 2021. Its been an i… [+5456 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Connie Loizos',
#    'title': 'Michael Arrington’s next act',
#    'description': 'As longtime TechCrunch readers know well, Michael Arrington cofounded TechCrunch and Crunchbase, as well as the venture fund CrunchFund, which was later renamed Tuesday Capital. But In 2017, Arrington announced that he was shifting gears and becoming a full-t…',
#    'url': 'http://techcrunch.com/2021/07/21/michael-arringtons-next-act/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2014/05/michael-arrington.jpg?w=600',
#    'publishedAt': '2021-07-21T22:00:14Z',
#    'content': 'As longtime TechCrunch readers know well, Michael Arrington cofounded TechCrunch and Crunchbase, as well as the venture fund CrunchFund, which was later renamed Tuesday Capital. But In 2017, Arringto… [+12730 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'Coinbase crushes Q2 expectations, notes Q3 trading volume is trending lower',
#    'description': 'After the bell today, Coinbase reported another period of impressive results in its second quarter earnings report. During the quarter, Coinbase’s total revenue reached $2.23 billion, which helped the company generate net income of $1.61 billion in the three-…',
#    'url': 'http://techcrunch.com/2021/08/10/coinbase-crushes-q2-expectations-notes-q3-trading-volume-is-trending-lower/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/04/GettyImages-1304243736.jpeg?w=669',
#    'publishedAt': '2021-08-10T21:06:43Z',
#    'content': 'After the bell today, Coinbase reported another period of impressive results in its second quarter earnings report.\r\nDuring the quarter, Coinbase’s total revenue reached $2.23 billion, which helped t… [+4900 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin rises above $40000 - Reuters',
#    'description': 'Bitcoin broke above $40,000 on Wednesday and headed for another attempt at breaking from its monthslong range as short sellers bailed out and traders drew confidence from recent positive comments about the cryptocurrency by high-profile investors.',
#    'url': 'https://www.reuters.com/business/bitcoin-rises-above-40000-2021-07-28/',
#    'urlToImage': 'https://www.reuters.com/resizer/mn9bccLH3-G_DGBZey3D9AAK6BU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/54S6UHTUFNO2JEREAW23MMRI6M.jpg',
#    'publishedAt': '2021-07-28T02:27:00Z',
#    'content': 'SINGAPORE, July 28 (Reuters) - Bitcoin broke above $40,000 on Wednesday and headed for another attempt at breaking from its monthslong range as short sellers bailed out and traders drew confidence fr… [+351 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': 'T-Mobile investigates claims of giant customer data breach',
#    'description': 'T-Mobile is grappling with yet another reported data breach. The carrier told Motherboard in a statement that it\'s investigating an "underground forum" member\'s claims that they\'re selling data for over 100 million customers, including social security numbers…',
#    'url': 'https://www.engadget.com/t-mobile-data-breach-investigation-202913474.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-08/86bb4930-fe03-11eb-850f-41793e0d4d92',
#    'publishedAt': '2021-08-15T20:29:13Z',
#    'content': 'T-Mobile is grappling with yet another reported data breach. The carrier told Motherboard in a statement that it\'s investigating an "underground forum" member\'s claims that they\'re selling data for o… [+1118 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin rises 7.07% to $47587.38 - Reuters',
#    'description': 'Bitcoin  surged 7.07% to $47,587.38 at 2200 GMT on Friday, adding $3,142.93 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-707-4758738-2021-08-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/LcnGvi5sh8VWWqo7vm6NoHwCDOQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/F32JNXDLTRP7BJ4YAY7XD3QIEE.jpg',
#    'publishedAt': '2021-08-13T22:14:00Z',
#    'content': 'Representations of cryptocurrency Bitcoin are seen in this picture illustration taken June 7, 2021. REUTERS/Edgar Su/IllustrationAug 13 (Reuters) - Bitcoin surged 7.07% to $47,587.38 at 2200 GMT on F… [+418 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Queenie Wong',
#    'title': 'UK man arrested for massive Twitter hack that targeted Biden, Musk in 2020 - CNET',
#    'description': 'The hack was part of a Bitcoin scam.',
#    'url': 'https://www.cnet.com/tech/services-and-software/uk-man-arrested-for-massive-twitter-hack-that-targeted-biden-musk-in-2020/',
#    'urlToImage': 'https://www.cnet.com/a/img/yJgVkX8c019FEpdoCglxznp2yTs=/1200x630/2020/01/08/46dd9291-5232-4c79-a552-8a39dd0aad8a/twitter-9841.jpg',
#    'publishedAt': '2021-07-21T19:55:55Z',
#    'content': 'James Martin/CNET\r\nA UK man was arrested in Spain for his alleged role in a massive hack of high-profile Twitter accounts that targeted politicians\xa0and celebrities in 2020, the US Department of Justi… [+1397 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin climbs back over $30000 - Reuters',
#    'description': 'Bitcoin recovered from a one-month low and broke back above $30,000 on Wednesday, suggesting firm support around that level even as the mood in broader financial markets remained fragile.',
#    'url': 'https://www.reuters.com/technology/bitcoin-climbs-back-over-30000-2021-07-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/hmBFGEIgFFPAn1NFgqiYI5udcJ4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2FH7UIXJBVP2TAHSYVK2DJZSDE.jpg',
#    'publishedAt': '2021-07-21T06:31:00Z',
#    'content': 'A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/IllustrationSINGAPORE, July 21 (Reuters) - Bitcoin reco… [+497 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin climbs back over $30,000 - Reuters',
#    'description': 'Bitcoin recovered from a one-month low and broke back above $30,000 on Wednesday, suggesting firm support around that level even as the mood in broader financial markets remained fragile.',
#    'url': 'https://www.reuters.com/article/us-fintech-crypto-bitcoin-idUSKBN2ER0GD',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210721&t=2&i=1569490501&r=LYNXMPEH6K080&w=800',
#    'publishedAt': '2021-07-21T06:32:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nSINGAPORE (… [+410 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': '10 things before the opening bell',
#    'description': 'Tech earnings continue to beat expectations, Robinhood is under investigation, and a new bitcoin mutual fund.',
#    'url': 'https://www.businessinsider.com/10-things-before-the-opening-bell-july-29-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/60df6d2b7cd04c001a227c19?format=jpeg',
#    'publishedAt': '2021-07-29T10:33:52Z',
#    'content': "REUTERS/Dado Ruvic/Illustration\r\nWelcome to 10 Things Before the Opening Bell. If this was forwarded to you, sign up here.\r\nMarkets Insider is selling its first NFTs. Get the details here.\r\nLet's get… [+2549 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': "Tesla will 'most likely' restart accepting bitcoin as payments, says Musk - Reuters",
#    'description': 'Electric-car maker Tesla Inc <a href="https://www.reuters.com/companies/TSLA.O" target="_blank">(TSLA.O)</a> will most likely restart accepting bitcoin as payments, Chief Executive Officer Elon Musk said at a conference on Wednesday.',
#    'url': 'https://www.reuters.com/business/autos-transportation/tesla-will-most-likely-restart-accepting-bitcoin-payments-says-musk-2021-07-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/-IbAMiIDsvmSmvucUTS-TEVNc8U=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HJLMO2EG3BPODPG2Y2UNPAPOKY.jpg',
#    'publishedAt': '2021-07-21T18:53:00Z',
#    'content': 'Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin falls below $30000 for first time in a month - Reuters',
#    'description': 'Bitcoin  fell on Tuesday to its lowest in almost a month, slumping below $30,000 as regulators continued calls for tighter checks on cryptocurrencies.',
#    'url': 'https://www.reuters.com/technology/bitcoin-falls-below-30000-first-time-month-2021-07-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/Not3njwaoF1B8RgjAzvUcVNEBwQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WR4PRUNXJZPXZDFB2MVNW4EYY4.jpg',
#    'publishedAt': '2021-07-20T12:36:00Z',
#    'content': "LONDON, July 20 (Reuters) - Bitcoin fell on Tuesday to its lowest in almost a month, slumping below $30,000 as regulators continued calls for tighter checks on cryptocurrencies.\r\nThe world's largest … [+1100 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Amazon denies report of accepting bitcoin as payment - Reuters',
#    'description': 'Amazon.com Inc on Monday denied a media report saying the e-commerce giant was looking to accept bitcoin payments by the end of the year.',
#    'url': 'https://www.reuters.com/article/us-amazon-cryptocurrency-idUSKBN2EW2HT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210726&t=2&i=1570031458&r=LYNXMPEH6P1H2&w=800',
#    'publishedAt': '2021-07-26T21:48:00Z',
#    'content': 'By Reuters Staff\r\nAmazon app is seen on a smartphone in this illustration taken, July 13, 2021. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) - Amazon.com Inc on Monday denied a media report saying the … [+1079 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Tesla likely to take bitcoin again soon - Musk - Reuters.com',
#    'description': 'Tesla is likely to start taking bitcoin again, as long as it sees signs the e-coin is becoming more environmentally sustainable, says company boss Elon Musk.',
#    'url': 'https://www.reuters.com/video/watch/idPz6M?now=true',
#    'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/60f93df1e4b085d3b6c357ad-1626947057798?location=LANDSCAPE',
#    'publishedAt': '2021-07-22T10:30:12Z',
#    'content': 'Posted \r\nTesla is likely to start taking bitcoin again, as long as it sees signs the e-coin is becoming more environmentally sustainable, says company boss Elon Musk.'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lisa Mattackal',
#    'title': 'Upgrades, ESG, DeFi usage to help ether outpace bitcoin: Pantera Capital - Reuters',
#    'description': "The Ethereum platform's potential applications, lower environmental impact and technical upgrades are likely to help the ether token continue to outperform bitcoin, Pantera Capital CEO Dan Morehead said.",
#    'url': 'https://www.reuters.com/technology/upgrades-esg-defi-usage-help-ether-outpace-bitcoin-pantera-capital-2021-08-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/By5o9E8NDdOJpgM7cwR-NkTRl7k=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ZWIIX4554NNPTPHLLVWKT6FBZA.jpg',
#    'publishedAt': '2021-08-03T05:50:46Z',
#    'content': 'Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 3 (Reuters) - The Ethereum platform… [+2412 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Tim De Chant',
#    'title': 'Bitcoin surges as Amazon job posting suggests retailer may accept cryptocurrencies',
#    'description': 'Tech giant might be preparing a big move—or simply keeping an eye on the space.',
#    'url': 'https://arstechnica.com/tech-policy/2021/07/bitcoin-surges-as-amazon-job-posting-suggests-retailer-may-accept-cryptocurrencies/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2021/07/GettyImages-869023966-760x380.jpg',
#    'publishedAt': '2021-07-26T16:57:42Z',
#    'content': '22 with 21 posters participating\r\nAmazon posted a job opening late last week that suggested the e-commerce giant may be considering accepting cryptocurrencies as a form of payment.\r\nThe posting sent … [+6160 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Nicholas Pongratz',
#    'title': 'Bitcoin Miner Bit Digital Expanding With Second U.S. Office in Miami',
#    'description': 'Bitcoin miner Bit Digital said it would be leasing space in Miami Beach for its second US location.',
#    'url': 'https://beincrypto.com/bit-digital-expanding-with-miami-office/',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/be-in-crypto/hero-image-be-in-crypto-378263.jpeg',
#    'publishedAt': '2021-07-23T16:14:48Z',
#    'content': 'This story originally appeared on be[IN]cryptoBitcoin miner Bit Digital said it would be leasing space in Miami Beach for its second U.S. location.\r\nThe new office will be managed and overseen by Bit… [+1832 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': "Cryptocurrencies' market cap has risen above $2 trillion for the first time since May as bitcoin rebounds",
#    'description': 'Bitcoin, ether, and other cryptocurrencies such as ada have rebounded sharply in recent weeks.',
#    'url': 'https://markets.businessinsider.com/news/stocks/crypto-market-cap-2-trillion-bitcoin-ether-ada-rebound-2021-8',
#    'urlToImage': 'https://images2.markets.businessinsider.com/611912163dd01000199dc0ec?format=jpeg',
#    'publishedAt': '2021-08-15T13:43:30Z',
#    'content': 'Cryptocurrencies have been on a wild ride in 2021.\r\nYuriko Nakao/Getty Images\r\nThe market capitalization of the cryptocurrency universe has broken the $2 trillion barrier for the first time since May… [+2169 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Staff',
#    'title': 'Amazon Posts Crypto Job Listing, Bitcoin Skyrockets',
#    'description': 'Bitcoin hit a six-week high of nearly $39,043 and Ethereum hit $2,363.',
#    'url': 'https://www.entrepreneur.com/article/378516',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627393951-shutterstock-1922249036.jpg',
#    'publishedAt': '2021-07-27T13:52:40Z',
#    'content': 'Cryptocurrencies spiked Monday after Amazon listed an open job for a digital currency and blockchain product lead.\xa0\r\nAmazon is known for plummeting the stocks of would-be rivals whenever rumors swirl… [+1425 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Platzi revives MC Dinero in a commercial for his cryptocurrency classes',
#    'description': '"The world is consumed in money, but now with bitcoin I do what I want."',
#    'url': 'https://www.entrepreneur.com/article/379611',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1628278369-MCDinero-Platzi.jpg',
#    'publishedAt': '2021-08-06T19:35:42Z',
#    'content': 'August\r\n6, 2021\r\n3 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nJust as many recognize the child of the OXXO and many o… [+2239 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Square to create new bitcoin-focused business - Reuters',
#    'description': 'Fintech company Square Inc <a href="https://www.reuters.com/companies/SQ.N" target="_blank">(SQ.N)</a> is creating a new business focused on bitcoin , Chief Executive Officer Jack Dorsey said in a tweet on Thursday.',
#    'url': 'https://www.reuters.com/technology/square-create-new-bitcoin-focused-business-2021-07-15/',
#    'urlToImage': 'https://www.reuters.com/resizer/3f40RrogLrg7oE57rv5TmKDcosU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/BLZPO6JV3FJKHOTI2O3AQB62HY.jpg',
#    'publishedAt': '2021-07-15T21:32:00Z',
#    'content': 'A Bitcoin (virtual currency) logo is pictured on a door in an illustration picture taken at La Maison du Bitcoin in Paris May 27, 2015. British authorities have come out in support of digital currenc… [+1290 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Bitcoin leaps 12% to test recent peaks - Reuters',
#    'description': 'Cryptocurrencies popped to the top of recent ranges on Monday as short sellers bailed out in the wake of a strong week and while traders hoped a handful of positive comments from influential investors might signal a turnaround. Ciara Lee reports',
#    'url': 'https://www.reuters.com/video/watch/idOVENHFS0B',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20210726&i=OVENHFS0B&r=OVENHFS0B&t=2',
#    'publishedAt': '2021-07-26T10:29:35Z',
#    'content': 'Posted \r\nCryptocurrencies popped to the top of recent ranges on Monday as short sellers bailed out in the wake of a strong week and while traders hoped a handful of positive comments from influential… [+54 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Bitcoin posts outflow for 2nd straight week -CoinShares data - Reuters',
#    'description': "Bitcoin investment products and funds registered outflows for a second consecutive week, according to data from digital asset manager CoinShares released on Monday, highlighting investors' cautious sentiment on the cryptocurrency sector as prices continued to…",
#    'url': 'https://www.reuters.com/business/finance/bitcoin-posts-outflow-2nd-straight-week-coinshares-data-2021-07-19/',
#    'urlToImage': 'https://www.reuters.com/resizer/a58gtAekkZv_z0s5vk6VtAq6V1s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/R4BNECSQXFO65GX7IEHVWAGV5U.jpg',
#    'publishedAt': '2021-07-19T16:36:00Z',
#    'content': 'Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/IllustrationNEW YORK, July 19 (Reuters) - Bitcoin investment products and fund… [+2098 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Amazon denies report of accepting bitcoin as payment - Reuters',
#    'description': 'Amazon.com Inc <a href="https://www.reuters.com/companies/AMZN.O" target="_blank">(AMZN.O)</a> on Monday denied a media report saying the e-commerce giant was looking to accept bitcoin payments by the end of the year.',
#    'url': 'https://www.reuters.com/business/retail-consumer/amazon-denies-report-accepting-bitcoin-payment-2021-07-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/vzyVZNYb3sTbmX-1qJs_97PtcAQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2FLTFM4A7JJMBFPK6X54YXPVXQ.jpg',
#    'publishedAt': '2021-07-26T21:52:00Z',
#    'content': "July 26 (Reuters) - Amazon.com Inc (AMZN.O) on Monday denied a media report saying the e-commerce giant was looking to accept bitcoin payments by the end of the year.\r\nThe report from London's City A… [+1100 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Tesla likely to take bitcoin again soon - Musk - Reuters',
#    'description': 'Tesla is likely to start taking bitcoin again, as long as it sees signs the e-coin is becoming more environmentally sustainable, says company boss Elon Musk. Julian Satterthwaite reports.',
#    'url': 'https://www.reuters.com/video/watch/idOVEMXGKGB',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20210722&i=OVEMXGKGB&r=OVEMXGKGB&t=2',
#    'publishedAt': '2021-07-22T10:20:19Z',
#    'content': 'Posted \r\nTesla is likely to start taking bitcoin again, as long as it sees signs the e-coin is becoming more environmentally sustainable, says company boss Elon Musk. Julian Satterthwaite reports.'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Crypto sector sees outflows for 4th week in a row, CoinShares data shows - Reuters',
#    'description': 'Cryptocurrency investment products and funds posted outflows for a fourth consecutive week, the bulk of which came from bitcoin products, which also experienced its fourth straight weekly outflow, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/business/finance/crypto-sector-sees-outflows-4th-week-row-coinshares-data-shows-2021-08-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/lmbIm3yyzD-3zaKlFvxHzYrSWHw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KEMQM7X26VP4DOPR5PQ5ODM4HY.jpg',
#    'publishedAt': '2021-08-02T20:10:00Z',
#    'content': 'A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Illustration/FilesNEW YORK, Aug 2 (Reuters) - Cryptocurrency investme… [+2265 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ilee@insider.com (Isabelle Lee)',
#    'title': "Cathie Wood doubles down on defense of bitcoin as environmentally conscious, and says there is 'nothing better' in terms of ESG",
#    'description': '"Bitcoin mining will probably become part of utility ecosystems, and will proliferate renewables faster than would otherwise be the case," Wood said.',
#    'url': 'https://markets.businessinsider.com/currencies/news/cathie-wood-ark-bitcoin-esg-cryptocurrency-environmentally-conscious-btc-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/5efb966a988ee3651a515969?format=jpeg',
#    'publishedAt': '2021-07-15T16:25:09Z',
#    'content': 'ARK Invest\r\nCathie Wood doubled down on her defense of bitcoin as "environmentally conscious", bucking criticism of major figures, including Elon Musk, fn the asset\'s harmful ecological impact.\r\n"The… [+2038 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'egraffeo@businessinsider.com (Emily Graffeo)',
#    'title': 'Bitcoin mining stocks surge as the cryptocurrency rallies towards $40,000',
#    'description': 'Mining stocks tend to move in the same direction as bitcoin, though many have outperformed the cryptocurrnency in 2021.',
#    'url': 'https://markets.businessinsider.com/news/stocks/marathon-riot-blockchain-stock-price-bitcoin-rally-mining-crypto-bitfarms-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/60e6e6a285fa170018522a87?format=jpeg',
#    'publishedAt': '2021-07-26T13:29:51Z',
#    'content': 'Critics argue that the energy-intensive bitcoin mining process is bad for the planet.\r\nLars Hagberg/Getty Images\r\nShares of cryptocurrency mining companies soared in early Monday morning trading as b… [+1207 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ilee@insider.com (Isabelle Lee)',
#    'title': "The first widely available bitcoin mutual fund is now available for investors who don't want to buy the coin itself",
#    'description': 'ProFunds said the new mutual fund eliminates the need for investors to hold their bitcoin through exchanges or wallets.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-mutual-fund-profunds-futures-contracts-cryptocurrency-btc-strategy-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/6101a309f350d500195975c7?format=jpeg',
#    'publishedAt': '2021-07-28T19:23:59Z',
#    'content': 'Nicolas Economou/NurPhoto via Getty Images\r\nA new mutual fund will allow traders to invest in bitcoin without going through the process of buying the asset itself.\r\nProFunds on Wednesday launched Bit… [+1274 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "Elon Musk says Tesla's caused him two-thirds of the personal and professional pain he's ever felt",
#    'description': '"This is a hella hard situation," Musk told Twitter CEO Jack Dorsey in a chat about bitcoin on Wednesday.',
#    'url': 'https://www.businessinsider.com/elon-musk-two-thirds-personal-professional-pain-tesla-2021-7',
#    'urlToImage': 'https://i.insider.com/60f870b30729770012b92177?width=1200&format=jpeg',
#    'publishedAt': '2021-07-21T19:47:43Z',
#    'content': 'Elon Musk said two-thirds of the "personal and professional pain" he\'s experienced has stemmed from running Tesla.\xa0\r\nIn a virtual bitcoin conference with Twitter CEO Jack Dorsey, Musk who\'s also CEO … [+1574 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ilee@insider.com (Isabelle Lee)',
#    'title': "Michael Saylor says bitcoin has elevated Microstrategy's brand and doubts politicians like Elizabeth Warren fully understand the cryptocurrency",
#    'description': '"Bitcoin has done wonders for our brand. It\'s elevated our brand by a factor of a hundred," Saylor told CNBC.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-microstrategy-brand-michael-saylor-elizabeth-warren-cryptocurrency-facebook-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61042fb439e63d001884a9bf?format=jpeg',
#    'publishedAt': '2021-07-30T18:31:29Z',
#    'content': "MicroStrategy CEO Michael Saylor and Sen. Elizabeth Warren.\r\nJoe Raedle/Getty Images (for Saylor) and Greg Nash-Pool/Getty Images (for Warren)\r\nMichael Saylor says he believes MicroStrategy's associa… [+2333 chars]"},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Nicholas Pongratz',
#    'title': 'Bitcoin Mutual Fund Hits the Market as Crypto ETP Race Heats Up',
#    'description': 'Maryland-based ProFunds is launching a publicly available mutual fund connected to the value of bitcoin (BTC).',
#    'url': 'https://beincrypto.com/bitcoin-mutual-fund-hits-the-market-as-crypto-etp-race-heats-up/',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/be-in-crypto/hero-image-be-in-crypto-378754.jpeg',
#    'publishedAt': '2021-07-29T11:45:36Z',
#    'content': 'This story originally appeared on be[IN]cryptoMaryland-based ProFunds is launching a publicly available mutual fund connected to the value of bitcoin (BTC).\r\nThe Bitcoin Strategy ProFund invests in b… [+1875 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': 'Best Bitcoin and crypto wallets for 2021 - CNET',
#    'description': 'The safest and most secure places to stash your cryptocurrency.',
#    'url': 'https://www.cnet.com/personal-finance/investing/the-best-bitcoin-and-crypto-wallets-for-2021/',
#    'urlToImage': 'https://www.cnet.com/a/img/gazdKK5fGAOLXDO7pUIX-3bTkVM=/1200x630/right/middle/2021/05/19/2c0b9d64-e53f-483b-a658-47d6592a6328/gettyimages-1064373134.jpg',
#    'publishedAt': '2021-07-30T11:00:07Z',
#    'content': "Prices go up, prices go down -- but Bitcoin is here to stay. And as cryptocurrency continues its march toward the mainstream, and becomes more entwined with the global economy, sooner or later you're… [+10626 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'JP Morgan changed his mind and went from criticizing Bitcoin to integrating it into his investment options',
#    'description': 'Although the CEO of financial firm JP Morgan was one of the main detractors of Bitcoin and cryptocurrencies, he has already given in to their charm and now they will offer BTC funds to their clients.',
#    'url': 'https://www.entrepreneur.com/article/379597',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1628274289-Ago6JPMorganBitcoininversionesfondocriptomonedas.jpg',
#    'publishedAt': '2021-08-06T18:24:00Z',
#    'content': 'August\r\n6, 2021\r\n3 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nCriptomonedas the boom in the last year and a half has … [+2473 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lisa Mattackal',
#    'title': "Neuberger Berman's commodity fund to invest in cryptocurrency derivatives - Reuters",
#    'description': 'Asset manager Neuberger Berman gave its Commodity Strategy Fund  the green light to invest indirectly in cryptocurrencies, a regulatory filing showed.',
#    'url': 'https://www.reuters.com/technology/neuberger-bermans-commodity-fund-invest-cryptocurrency-derivatives-2021-08-12/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=49',
#    'publishedAt': '2021-08-12T20:12:00Z',
#    'content': 'Aug 12 (Reuters) - Asset manager Neuberger Berman gave its Commodity Strategy Fund the green light to invest indirectly in cryptocurrencies, a regulatory filing showed.\r\nThe $164.4 million mutual fun… [+1068 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Huw Jones',
#    'title': 'EU to tighten rules on cryptoasset transfers - Reuters',
#    'description': 'Companies that transfer bitcoin or other cryptoassets must collect details of senders and recipients to help authorities crack down on dirty money, EU policymakers proposed on Tuesday in the latest efforts to tighten regulation of the sector.',
#    'url': 'https://www.reuters.com/technology/eu-tighten-rules-cryptoasset-transfers-2021-07-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/InHvCiSZm4U-VU8bDnCg_6ScF8s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/UGHMBKNQAJIUNAN7OCRGXCKYOM.jpg',
#    'publishedAt': '2021-07-20T14:35:00Z',
#    'content': 'July 20 (Reuters) - Companies that transfer bitcoin or other cryptoassets must collect details of senders and recipients to help authorities crack down on dirty money, EU policymakers proposed on Tue… [+1690 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Bitcoin, cryptos post 5th straight week of outflows -CoinShares data - Reuters',
#    'description': 'Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scrutiny, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/technology/bitcoin-cryptos-post-5th-straight-week-outflows-coinshares-data-2021-08-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/_5lTYPm4R5fFav9Ag5rmRlahRis=/800x419/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7YZMDMXDOVMOZNMBSLVCED2KEU.jpg',
#    'publishedAt': '2021-08-09T20:21:00Z',
#    'content': 'A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, Aug 9 (Reuters) - Bitcoin investment products and funds register… [+2160 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Matthew De Saro',
#    'title': 'Global X Becomes Latest Firm to File for Bitcoin ETF',
#    'description': 'Exchange-traded fund (ETF) provider, Global X, has submitted a filing of its own with the SEC for a bitcoin ETF.',
#    'url': 'https://beincrypto.com/global-x-files-for-a-bitcoin-etf-with-the-sec/',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/be-in-crypto/hero-image-be-in-crypto-378173.jpeg',
#    'publishedAt': '2021-07-22T20:00:00Z',
#    'content': 'This story originally appeared on be[IN]cryptoExchange-traded fund (ETF) provider, Global X, has submitted a filing of its own with the SEC for a bitcoin ETF.\xa0\r\nGlobal X joined the myriad of companie… [+2345 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'AMC Entertainment will have technology to receive bitcoin as payment by year-end - CEO - Reuters',
#    'description': "Cinema operator AMC Entertainment will have the technology in place to receive payment in bitcoin by the end of the year as payment for movie tickets and concessions, the company's CEO said on a call discussing its results.",
#    'url': 'https://www.reuters.com/article/us-amc-ent-holdg-results-bitcoin-idUSKBN2FA21F',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210809&t=2&i=1571459626&r=LYNXMPEH780ZK&w=800',
#    'publishedAt': '2021-08-09T21:51:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: An AMC theatre is pictured amid the coronavirus disease (COVID-19) pandemic in the Manhattan borough of New York City, New York, U.S., January 27, 2021. REUTERS/Carlo Al… [+240 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'Bitcoin, cryptos post 5th straight week of outflows -CoinShares data - Reuters',
#    'description': 'Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scrutiny, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/article/legal-us-fintech-crypto-flows-idUSKBN2FB1DO',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210810&t=2&i=1571521012&r=LYNXMPEH790MV&w=800',
#    'publishedAt': '2021-08-10T14:19:00Z',
#    'content': 'NEW YORK (Reuters) - Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scruti… [+2022 chars]'},
#   {'source': {'id': None, 'name': 'MarketBeat'},
#    'author': 'Sean Sechler',
#    'title': '3 Crypto Stocks for Bitcoin Bulls to Buy Now',
#    'description': 'These companies offer an attractive way to gain exposure to cryptocurrencies through equities and could be poised for strong outperformance in the com...',
#    'url': 'https://www.marketbeat.com/originals/3-crypto-stocks-for-bitcoin-bulls-to-buy-now/?utm_source=entrepreneurcom&amp;amp;utm_medium=entrepreneurcom',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/marketbeat/hero-image-marketbeat-379820.jpeg',
#    'publishedAt': '2021-08-10T09:01:00Z',
#    'content': 'August\r\n10, 2021\r\n5 min read\r\nThis story originally appeared on MarketBeat\r\nAlthough cryptocurrencies such as Bitcoin have taken investors on a wild ride in 2021, these intriguing digital assets cont… [+4736 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Staff',
#    'title': "Elon Musk Says Tesla Will 'Likely' Accept Bitcoin Again",
#    'description': 'During a live-streamed conversation with Twitter founder Jack Dorsey for the B Word Conference, Musk said "It looks like bitcoin is shifting a lot more towards renewables."',
#    'url': 'https://www.entrepreneur.com/article/378104',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1626964667-GettyImages-1130611974.jpg',
#    'publishedAt': '2021-07-22T14:38:01Z',
#    'content': 'Elon Musk said Wednesday that his company, Tesla, would “most likely” accept Bitcoin again in the future.\xa0\r\nDuring a live-streamed conversation with Twitter founder Jack Dorsey for the B Word Confere… [+1227 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "Twitter CEO Jack Dorsey says bitcoin's 'weird as hell' community inspires him and reminds him of the internet's early days",
#    'description': '"It\'s the only reason that I have a career - because I learned so much from people like who are building bitcoin today," Dorsey said.',
#    'url': 'https://www.businessinsider.com/twitter-jack-dorsey-bitcoin-community-weird-as-hell-inspiration-2021-7',
#    'urlToImage': 'https://i.insider.com/60f8797ffc253600181fae19?width=1200&format=jpeg',
#    'publishedAt': '2021-07-21T20:28:48Z',
#    'content': 'Twitter CEO Jack Dorsey said part of what drives his passion for bitcoin is its community, which he described as being "weird as hell."\r\nDorsey chatted everything related to the digital asset in a vi… [+1407 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Bitcoin rises 10% as Elon Musk, Jack Dorsey, and Cathie Wood gather to discuss the volatile cryptocurrency',
#    'description': "Technical analysts view bitcoin's $30,000 level as a make or break support level that could lead to significant downside if it doesn't hold.",
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-price-gains-elon-musk-jack-dorsey-cathie-wood-crypto-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/60119de56dfbe10018e00431?format=jpeg',
#    'publishedAt': '2021-07-21T19:34:01Z',
#    'content': "David McNew/AFP via Getty; ARK Invest; Patricia De Melo Moreira/AFP via Getty; Bitcoin; Samantha Lee/Insider\r\nBitcoin's surged as much as 10% on Wednesday as Tesla CEO Elon Musk, Square CEO Jack Dors… [+1935 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Bitcoin is set up for at least 30% more upside after surging above a key technical level and with near-term momentum shifting positive',
#    'description': '"Importantly, both bitcoin and Ether have cleared their 50-day MAs on newly positive short-term momentum," Katie Stockton of Fairlead Strategies said.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-price-outlook-passing-key-technical-level-moving-average-btc-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/60feddaa0d35a900182528a0?format=jpeg',
#    'publishedAt': '2021-07-26T17:19:43Z',
#    'content': 'Bitcoin has fallen more than 40% from its April record high.\r\nMarco Bello/Getty Images\r\n<ul><li>Bitcoin cleared its 50-day moving average on Sunday, setting the cryptocurrency up for more gains ahead… [+1955 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': "Bitcoin is at a 'do-or-die' moment and could surge if it can hold above $40,000, analysts say",
#    'description': 'Bitcoin has had a stellar rally, rising for eight days straight after Elon Musk made positive comments and Amazon appeared interested in crypto.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-price-outlook-btc-rally-40000-level-crypto-elon-musk-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/6094454df22c6b00185dcbd9?format=jpeg',
#    'publishedAt': '2021-07-29T10:23:11Z',
#    'content': 'Bitcoin has climbed sharply in recent days.\r\nREUTERS/Dado Ruvic\r\nBitcoin is facing a "do-or-die" moment and could move sharply higher if it can hold on to the stellar weekly gains that have taken it … [+2315 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': 'The history of hacking ransoms and cryptocurrency - CNET',
#    'description': 'Malware attacks across the globe now come at whirlwind speed.',
#    'url': 'https://www.cnet.com/personal-finance/investing/the-history-of-hacking-ransoms-and-cryptocurrency/',
#    'urlToImage': 'https://www.cnet.com/a/img/8BbIHtexWHnd4Z6uZ1xs3j5TeiY=/1200x630/2021/07/23/fd1f2c12-d828-4d67-a652-c16e79a9dbc5/gettyimages-1163756528.jpg',
#    'publishedAt': '2021-07-30T11:00:12Z',
#    'content': 'Getty Images\r\nEarlier this month, hundreds of companies from the US to Sweden were entangled in the\xa0Kaseya ransomware attack\xa0on Kaseya, which provides network infrastructure for businesses around the… [+10000 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Square To Create New Bitcoin Platform for Financial Services',
#    'description': 'Payments services company Square will open a new business focused on creating an "open developer platform" to make it easier to provide non-custodial, decentralized financial services, CEO Jack Dorsey said Thursday in a series of tweets. From a report: The st…',
#    'url': 'https://slashdot.org/story/21/07/21/1931240/square-to-create-new-bitcoin-platform-for-financial-services',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-07-21T20:05:00Z',
#    'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Bitcoin Crashes Below $30,000 As Cryptocurrency Free-Fall Accelerates',
#    'description': 'The price of bitcoin has come crashing below the $30,000 mark for the first time in a month. "At the time of this writing, Bitcoin is trading at $29,694.34," writes Paul Lilly via HotHardware. "That\'s down from around $31,000 yesterday, and less than half of …',
#    'url': 'https://news.slashdot.org/story/21/07/20/2042215/bitcoin-crashes-below-30000-as-cryptocurrency-free-fall-accelerates',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-07-20T23:20:00Z',
#    'content': 'Will it go back up? Probably, but for Bitcoin investors, there are definitely reasons to be cautious, outside of the normal volatility associated with cryptocurrencies. For one, China is crackingdown… [+1231 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'More Bitcoin Miners Head to America, Partly for Cheaper Energy',
#    'description': '"Well before China decided to kick out all of its bitcoin miners, they were already leaving in droves, and new data from Cambridge University shows they were likely headed to the United States," reports CNBC:\n\nThe U.S. has fast become the new darling of the b…',
#    'url': 'https://news.slashdot.org/story/21/07/17/2235201/more-bitcoin-miners-head-to-america-partly-for-cheaper-energy',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-07-18T15:34:00Z',
#    'content': "The U.S. has fast become the new darling of the bitcoin mining world. It is the second-biggest mining destination on the planet, accounting for nearly 17% of all the world's bitcoin miners as of Apri… [+1732 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Why a Waste-Coal Power Plant is 'Burning for Bitcoin'",
#    'description': 'While some bitcoin mining operations are now looking to nuclear power, the Associated Press reports, Bill Spence (and his company Stronghold Digital Mining) is creating crypto-mining hubs out of waste coal power plants. (Text-only version here):\n\nThe plant he…',
#    'url': 'https://news.slashdot.org/story/21/08/08/0132207/why-a-waste-coal-power-plant-is-burning-for-bitcoin',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/earth_64.png',
#    'publishedAt': '2021-08-08T01:34:00Z',
# ...
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Viral Video Shows Malaysian Police Destroying 1,069 Bitcoin Mining Rigs With a Steamroller',
#    'description': 'Malaysian authorities seized 1,069 bitcoin mining rigs, laid them out in a parking lot at police headquarters, and used a steamroller to crush them, as part of a joint operation between law enforcement in the city of Miri and electric utility Sarawak Energy. …',
#    'url': 'https://slashdot.org/story/21/07/19/2023209/viral-video-shows-malaysian-police-destroying-1069-bitcoin-mining-rigs-with-a-steamroller',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-07-19T22:40:00Z',
#    'content': 'Assistant Commissioner of Police Hakemal Hawari told CNBC the crackdown came after miners allegedly stole $2 million worth of electricity siphoned from Sarawak Energy power lines. A video of the even… [+868 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Richard Dal Porto',
#    'title': 'Daily Crunch: India’s most valuable startup buys US-based digital reading platform Epic for $500M',
#    'description': 'Hello friends and welcome to Daily Crunch, bringing you the most important startup, tech and venture capital news in a single package.',
#    'url': 'http://techcrunch.com/2021/07/21/daily-crunch-indias-most-valuable-startup-buys-us-based-digital-reading-platform-epic-for-500m/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/07/byjus.jpg?w=599',
#    'publishedAt': '2021-07-21T22:10:02Z',
#    'content': 'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox every day at 3 p.m. PDT, subscribe here.\r\nHello and welcome to Extra Crunch for July 21, 2021. Its been a go… [+7010 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'kduffy@insider.com (Kate Duffy)',
#    'title': 'Watch Malaysian police use a steamroller to crush 1,069 bitcoin mining rigs worth $1.3 million',
#    'description': 'Police seized the rigs from miners who allegedly stole $2 million worth of electricity.',
#    'url': 'https://www.businessinsider.com/malaysian-police-steamroll-1069-bitcoin-mining-rigs-video-2021-7',
#    'urlToImage': 'https://i.insider.com/60f546d6bc757c001904b982?width=1200&format=jpeg',
#    'publishedAt': '2021-07-19T10:22:29Z',
#    'content': 'Malaysian police used a steamroller to crush 1,069 bitcoin mining computers seized in a series of raids, local media reported Friday.\r\nA video posted by the Borneo news outlet Dayak Daily shows the s… [+1208 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Rahul Nambiampurath',
#    'title': 'Goldman Sachs Submits DeFi ETF Application to SEC',
#    'description': 'Goldman Sachs has filed an application for a decentralized finance (DeFi) exchange-traded fund (ETF) with the U.S. SEC. The ETF will track an index th...',
#    'url': 'https://beincrypto.com/goldman-sachs-submits-defi-etf-application-to-sec/',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/be-in-crypto/hero-image-be-in-crypto-378496.jpeg',
#    'publishedAt': '2021-07-27T10:00:43Z',
#    'content': 'This story originally appeared on be[IN]cryptoGoldman Sachs has filed an application for a decentralized finance (DeFi) exchange-traded fund (ETF) with the U.S. SEC. The ETF will track an index that … [+2374 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jciolli@businessinsider.com (Joe Ciolli)',
#    'title': '13 must-see charts, plus an $875 mini bitcoin-mining rig',
#    'description': 'The definitive collection of the best investing stories Business Insider published during the week ended July 24.',
#    'url': 'https://www.businessinsider.com/13-charts-mini-bitcoin-mining-rigs-grayscale-ceo-insider-investing-2021-7',
#    'urlToImage': 'https://i.insider.com/609d7b5b070a690018af521e?width=1200&format=jpeg',
#    'publishedAt': '2021-07-25T19:35:00Z',
#    'content': "Hello and welcome to Insider Investing. I'm Joe Ciolli, and I'm here to guide you through the current market and investing landscape. Here's what's on the docket:\r\nIf you aren't yet a subscriber to I… [+1142 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Messi: What are the PSG fan tokens given to the footballer?',
#    'description': 'Paris St-Germain has given Messi a "large number" of fan tokens as part of his welcome package.',
#    'url': 'https://www.bbc.co.uk/news/world-58094912',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/0209/production/_119912500_b5cd812c-d88a-4ece-b322-9343eb3ee8ca.jpg',
#    'publishedAt': '2021-08-12T14:05:17Z',
#    'content': "image captionPSG says it gave the star a 'large amount' of fan tokens\r\nFootball star Lionel Messi signed with Paris St-Germain (PSG) earlier this week after his shock exit from Barcelona. \r\nAs part o… [+1560 chars]"},
#   {'source': {'id': None, 'name': 'Fox Business'},
#    'author': 'Ken Martin',
#    'title': 'Bitcoin price hovers around $40,000',
#    'description': '',
#    'url': 'https://www.foxbusiness.com/markets/bitcoin-price-7-29',
#    'urlToImage': 'https://a57.foxnews.com/static.foxbusiness.com/foxbusiness.com/content/uploads/2020/06/0/0/bitcoin-iStock.jpg?ve=1&tl=1',
#    'publishedAt': '2021-07-29T08:40:26Z',
#    'content': 'Bitcoin\r\n is slightly higher Thursday morning, trading just below the $40,000 level.\r\nThe price was around $39,800 per coin, while rivals Ethereum and Dogecoin\r\n were trading around $2,290 and 20 cen… [+1727 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Staff',
#    'title': 'You Will Soon Be Able to Use Bitcoin at This Movie Theatre Chain',
#    'description': 'Apple Pay and Google Pay will also soon be accepted for online purchases at U.S. theaters.',
#    'url': 'https://www.entrepreneur.com/article/379852',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1628607071-GettyImages-1224822957.jpg',
#    'publishedAt': '2021-08-10T14:51:36Z',
#    'content': 'August\r\n10, 2021\r\n2 min read\r\nAMCannounced Monday that American movie-goers can soon use bitcoin to pay for tickets and concessions. Apple Pay and Google Pay will also soon be accepted for online pur… [+1560 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Kirsten Korosec',
#    'title': 'Tesla’s quarterly profit surpasses $1 billion',
#    'description': 'Tesla reported Monday an eye-popping $1.14 billion in net income in the second quarter, results that blew past analyst expectations and marked the first time the company’s quarterly profit (on a GAAP basis) has passed the three-comma threshold. The results pu…',
#    'url': 'http://techcrunch.com/2021/07/26/teslas-quarterly-profit-surpasses-1-billion/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/06/Screen-Shot-2021-06-11-at-3.04.45-pm.png?w=764',
#    'publishedAt': '2021-07-26T20:58:30Z',
#    'content': 'Tesla reported Monday an eye-popping $1.14 billion in net income in the second quarter, results that blew past analyst expectations and marked the first time the company’s quarterly profit (on a GAAP… [+2627 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sujata Rao',
#    'title': 'Euro just off 3-1/2-mth low vs dollar pre-ECB - Reuters',
#    'description': 'The euro traded just off 3-1/2 month lows versus the dollar on Thursday before a potentially momentous meeting of the ECB, while growth-focused currencies such as the Australian dollar gained as a global risk sell-off abated further.',
#    'url': 'https://www.reuters.com/business/euro-just-off-3-12-mth-low-vs-dollar-pre-ecb-2021-07-22/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=48',
#    'publishedAt': '2021-07-22T08:41:00Z',
#    'content': 'LONDON, July 22 (Reuters) - The euro traded just off 3-1/2 month lows versus the dollar on Thursday before a potentially momentous meeting of the ECB, while growth-focused currencies such as the Aust… [+3002 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sujata Rao',
#    'title': 'FOREX-Euro just off 3-1/2-mth low vs dollar pre-ECB - Reuters',
#    'description': '* Higher-risk currencies firmer; dollar and yen off multi-month highs',
#    'url': 'https://www.reuters.com/article/global-forex-idUSL8N2OY2CF',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-07-22T08:32:00Z',
#    'content': '* Euro weakens before crucial ECB meeting\r\n* Higher-risk currencies firmer; dollar and yen off multi-month highs\r\n* Graphic: World FX rates tmsnrt.rs/2RBWI5E\r\nLONDON, July 22 (Reuters) - The euro tra… [+2992 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'UPDATE 1-U.S. dollar net longs climb to highest since early March 2020 -CFTC, Reuters - Reuters',
#    'description': 'U.S. dollar net longs rose in the latest week to their highest level since early March last year, according to Reuters calculations and Commodity Futures Trading Commission data released on Friday. The value of the net long dollar position advanced to $2.99 b…',
#    'url': 'https://www.reuters.com/article/cftc-forex-idUSL1N2P62SB',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-07-30T20:49:00Z',
#    'content': '(Corrects dollar positioning to net long in 2nd paragraph)\r\n By Gertrude Chavez-Dreyfuss\r\n NEW YORK, July 30 (Reuters) - U.S. dollar net longs rose in\r\nthe latest week to their highest level since ea… [+3264 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Victor Chatenay)',
#    'title': 'Twitter and Amazon, learning from Facebook, make strides in crypto',
#    'description': "While Facebook's digital currency remains MIA, Twitter and Amazon are making their own headway in cryptos.",
#    'url': 'https://www.businessinsider.com/twitter-amazon-announce-crypto-plans-following-facebook-2021-7',
#    'urlToImage': 'https://i.insider.com/60f601d8bc757c001904bcad?width=1200&format=jpeg',
#    'publishedAt': '2021-07-27T13:31:10Z',
#    'content': "Twitter CEO Jack Dorsey confirmed in the company's Q2 earnings call that the social media platform will integrate Bitcoin into its services, and Amazon wants to let customers pay in cryptocurrencytak… [+2334 chars]"},
#   {'source': {'id': None, 'name': 'The Economist'},
#    'author': 'The Economist',
#    'title': 'What if bitcoin went to zero?',
#    'description': 'A thought experiment helps uncover the links between crypto and mainstream finance | Finance & economics',
#    'url': 'https://www.economist.com/finance-and-economics/2021/08/02/what-if-bitcoin-went-to-zero',
#    'urlToImage': 'https://www.economist.com/img/b/1280/720/90/sites/default/files/images/2021/08/articles/main/20210807_fnd001_0.jpg',
#    'publishedAt': '2021-08-02T00:00:00Z',
#    'content': 'THE RECENT expansion of the crypto-universe is a thing of wonder. Only a year ago there were about 6,000 currencies listed on CoinMarketCap, a website. Today there are 11,145. Their combined market c… [+9082 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Ariel Shapira',
#    'title': 'What the Most Recent Crypto Bull Run Means for DeFi',
#    'description': "As crypto's popularity continues to surge, the opportunities are endless.",
#    'url': 'https://www.entrepreneur.com/article/377830',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627050276-shutterstock-1976868902.jpg',
#    'publishedAt': '2021-07-27T13:15:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nFrom a late December pickup to the end of the rally in mid-April, Bitcoin sprung up by over 230%. And then with one announcement, it wa… [+7213 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Explainer: Major Ethereum upgrade set to alter supply, fix transaction fees - Reuters',
#    'description': 'Ethereum, the second-largest blockchain network, is about to undergo a technical adjustment that will significantly alter the way transactions are processed, as well as reduce the supply of the ether token and sharply boost its price.',
#    'url': 'https://www.reuters.com/technology/major-ethereum-upgrade-set-alter-supply-fix-transaction-fees-2021-07-30/',
#    'urlToImage': 'https://www.reuters.com/resizer/1WRoxyTTLAQrfsfda53TAlELBNA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/X45F5L2GXZI7DK4V4T7EGEUFWY.jpg',
#    'publishedAt': '2021-07-30T05:04:00Z',
#    'content': 'Representations of cryptocurrency Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, July 30 (Reuters) - Ethereum, the second-la… [+3949 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jonathan Stempel',
#    'title': 'New Jersey orders BlockFi cryptocurrency firm to stop offering interest-bearing accounts - Reuters',
#    'description': "New Jersey ordered the cryptocurrency platform BlockFi Inc to stop offering interest-bearing accounts that have raised $14.7 billion from investors, the state's acting attorney general said on Tuesday.",
#    'url': 'https://www.reuters.com/legal/transactional/new-jersey-orders-blockfi-cryptocurrency-firm-stop-offering-interest-bearing-2021-07-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/nY2gF9MNhdcsE3SDQozXlkxNzag=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HE2YNI4UKFOW5CYYYQFWKF25P4.jpg',
#    'publishedAt': '2021-07-20T17:25:41Z',
#    'content': 'Representations of virtual currency bitcoin on top of a U.S. dollar banknote are pictured through broken glass in this illustration taken June 25, 2021. REUTERS/Dado Ruvic/IllustrationJuly 20 (Reuter… [+1997 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Ritvik Carvalho',
#    'title': 'Dollar eases as focus turns to Fed, cryptocurrencies jump - Reuters',
#    'description': "The dollar slipped against a basket of currencies on Monday as investors turned their focus to this week's Federal Reserve meeting and cryptocurrencies jumped to their highest levels in weeks.",
#    'url': 'https://www.reuters.com/world/middle-east/dollar-eases-focus-turns-fed-cryptocurrencies-jump-2021-07-26/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=48',
#    'publishedAt': '2021-07-26T11:03:00Z',
#    'content': "LONDON, July 26 (Reuters) - The dollar slipped against a basket of currencies on Monday as investors turned their focus to this week's Federal Reserve meeting and cryptocurrencies jumped to their hig… [+2423 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Thomas Borrel',
#    'title': 'Why Energy Concerns Around Blockchain May Be a Misconception',
#    'description': "For those concerned about blockchain's energy consumption, it's important to consider the difference between proof-of-stake and proof-of-work blockchains.",
#    'url': 'https://www.entrepreneur.com/article/375742',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1626887066-shutterstock-749922058.jpg',
#    'publishedAt': '2021-07-25T12:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nFor business leaders that are on the fence about whether their company should use blockchain, conversations around blockchain’s energy … [+5531 chars]'}]}

# %%
# Fetch the Ethereum news articles

eth_all_articles = newsapi.get_everything(q='ethereum',
                                    language='en',
                                    page_size=100,
                                    sort_by='relevancy')

eth_all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 2773,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Connie Loizos',
#    'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’',
#    'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…',
#    'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667',
#    'publishedAt': '2021-07-16T16:00:55Z',
#    'content': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Tenderly raises $15.3M to help Ethereum developers ship decentralized apps faster',
#    'description': 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto space in 2021. The latest crypto startup to court the attenti…',
#    'url': 'http://techcrunch.com/2021/07/29/tenderly-raises-15-3m-to-help-ethereum-developers-ship-decentralized-apps-faster/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/07/Tenderly-Founding-Team-1.jpg?w=600',
#    'publishedAt': '2021-07-29T18:27:16Z',
#    'content': 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Amanda Silberling',
#    'title': 'Cent, the platform that Jack Dorsey used to sell his first tweet as an NFT, raises $3M',
#    'description': 'Cent was founded in 2017 as an ad-free creator network that allows users to offer each other crypto rewards for good posts and comments — it’s like gifting awards on Reddit, but with Ethereum. But in late 2020, Cent’s small, San Fransisco-based team created V…',
#    'url': 'http://techcrunch.com/2021/08/05/cent-the-platform-that-jack-dorsey-used-to-sell-his-first-tweet-as-an-nft-raises-3m/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/08/Screen-Shot-2021-08-04-at-1.13.16-PM.png?w=764',
#    'publishedAt': '2021-08-05T13:22:07Z',
#    'content': 'Cent was founded in 2017 as an ad-free creator network that allows users to offer each other crypto rewards for good posts and comments — it’s like gifting awards on Reddit, but with Ethereum. But in… [+6228 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'Coinbase crushes Q2 expectations, notes Q3 trading volume is trending lower',
#    'description': 'After the bell today, Coinbase reported another period of impressive results in its second quarter earnings report. During the quarter, Coinbase’s total revenue reached $2.23 billion, which helped the company generate net income of $1.61 billion in the three-…',
#    'url': 'http://techcrunch.com/2021/08/10/coinbase-crushes-q2-expectations-notes-q3-trading-volume-is-trending-lower/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/04/GettyImages-1304243736.jpeg?w=669',
#    'publishedAt': '2021-08-10T21:06:43Z',
#    'content': 'After the bell today, Coinbase reported another period of impressive results in its second quarter earnings report.\r\nDuring the quarter, Coinbase’s total revenue reached $2.23 billion, which helped t… [+4900 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Ethereum major upgrade activated; ether stays lower - Reuters',
#    'description': 'A major software upgrade on Ethereum, the second-largest blockchain network, was activated on Thursday, a move seen as stabilizing transaction fees on the network and subsequently reducing the supply of the ether token.',
#    'url': 'https://www.reuters.com/technology/ethereum-major-upgrade-activated-ether-stays-lower-2021-08-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/0BxXzmVhK1PkIw75bBwMHxbHzvY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/NENHSOKGOJMQVFJQB2ZPYW4D4E.jpg',
#    'publishedAt': '2021-08-05T12:48:00Z',
#    'content': 'Representation of the Ethereum virtual currency standing on the PC motherboard is seen in this illustration picture, February 3, 2018. REUTERS/Dado Ruvic/IllustrationNEW YORK, Aug 5 (Reuters) - A maj… [+439 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Ether near two-month high ahead of major protocol change - Reuters',
#    'description': 'Ether  held near two-month highs on Thursday ahead of a major adjustment to its underlying ethereum blockchain that would alter the way transactions are processed.',
#    'url': 'https://www.reuters.com/technology/ether-near-two-month-high-ahead-major-protocol-change-2021-08-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/cFw0DjmXRLhukvcucKWFA_xEpwM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WUIQVADLKZLG5CMD63VTG562AE.jpg',
#    'publishedAt': '2021-08-05T04:53:00Z',
#    'content': 'HONG KONG, Aug 5 (Reuters) - Ether held near two-month highs on Thursday ahead of a major adjustment to its underlying ethereum blockchain that would alter the way transactions are processed.\r\nThe re… [+1331 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lisa Mattackal',
#    'title': 'Upgrades, ESG, DeFi usage to help ether outpace bitcoin: Pantera Capital - Reuters',
#    'description': "The Ethereum platform's potential applications, lower environmental impact and technical upgrades are likely to help the ether token continue to outperform bitcoin, Pantera Capital CEO Dan Morehead said.",
#    'url': 'https://www.reuters.com/technology/upgrades-esg-defi-usage-help-ether-outpace-bitcoin-pantera-capital-2021-08-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/By5o9E8NDdOJpgM7cwR-NkTRl7k=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ZWIIX4554NNPTPHLLVWKT6FBZA.jpg',
#    'publishedAt': '2021-08-03T05:50:46Z',
#    'content': 'Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 3 (Reuters) - The Ethereum platform… [+2412 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Staff',
#    'title': 'Amazon Posts Crypto Job Listing, Bitcoin Skyrockets',
#    'description': 'Bitcoin hit a six-week high of nearly $39,043 and Ethereum hit $2,363.',
#    'url': 'https://www.entrepreneur.com/article/378516',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627393951-shutterstock-1922249036.jpg',
#    'publishedAt': '2021-07-27T13:52:40Z',
#    'content': 'Cryptocurrencies spiked Monday after Amazon listed an open job for a digital currency and blockchain product lead.\xa0\r\nAmazon is known for plummeting the stocks of would-be rivals whenever rumors swirl… [+1425 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Cryptocurrency heist hacker returns $260m in funds',
#    'description': 'The hacker behind the $600m Poly Network cryptocurrency heist has posted a Q&A on the blockchain.',
#    'url': 'https://www.bbc.co.uk/news/business-58180692',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/10F22/production/_119901496_hacking1.jpg',
#    'publishedAt': '2021-08-11T23:10:49Z',
#    'content': 'By Mary-Ann RussonBusiness reporter, BBC News\r\nThe hacker behind one of the largest ever cryptocurrency heists ever has returned almost half of the $600m (£433m) stolen assets.\r\nYesterday, blockchain… [+5117 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Ethereum Co-Founder Says Safety Concern Has Him Quitting Crypto',
#    'description': '"Anthony Di Iorio, a co-founder of the Ethereum network, says he\'s done with the cryptocurrency world, partially because of personal safety concerns," reports Bloomberg, in a story shared by Slashdot reader tekram:\n\nDi Iorio, 48, has had a security team since…',
#    'url': 'https://news.slashdot.org/story/21/07/17/004258/ethereum-co-founder-says-safety-concern-has-him-quitting-crypto',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/money_64.png',
#    'publishedAt': '2021-07-17T14:34:00Z',
#    'content': '"Anthony Di Iorio, a co-founder of the Ethereum network, says he\'s done with the cryptocurrency world, partially because of personal safety concerns," reports Bloomberg, in a story shared by Slashdot… [+1550 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Explainer: Major Ethereum upgrade set to alter supply, fix transaction fees - Reuters',
#    'description': 'Ethereum, the second-largest blockchain network, is about to undergo a technical adjustment that will significantly alter the way transactions are processed, as well as reduce the supply of the ether token and sharply boost its price.',
#    'url': 'https://www.reuters.com/technology/major-ethereum-upgrade-set-alter-supply-fix-transaction-fees-2021-07-30/',
#    'urlToImage': 'https://www.reuters.com/resizer/1WRoxyTTLAQrfsfda53TAlELBNA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/X45F5L2GXZI7DK4V4T7EGEUFWY.jpg',
#    'publishedAt': '2021-07-30T05:04:00Z',
#    'content': 'Representations of cryptocurrency Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, July 30 (Reuters) - Ethereum, the second-la… [+3949 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': 'More than $144 million of ether has been burned since major network upgrades hit ethereum last week',
#    'description': 'Investors have so far responded well to the ethereum network changes, with ether rising sharply since the fee-burn mechanism came into force.',
#    'url': 'https://www.businessinsider.com/ether-burn-ethereum-crypto-upgrade-eip1559-london-hard-fork-price-2021-8',
#    'urlToImage': 'https://i.insider.com/61168176c040ad0018ce298e?width=1200&format=jpeg',
#    'publishedAt': '2021-08-15T13:58:48Z',
#    'content': 'More than $144 million worth of ether has been burned since an overhaul of the fee system on the ethereum network went live on August 5.\r\nAs of Sunday, over 45,799 ether had been burned, according to… [+2017 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': 'More than $144 million of ether has been burned since major network upgrades hit ethereum last week',
#    'description': 'Investors have so far responded well to the ethereum network changes, with ether rising sharply since the fee-burn mechanism came into force.',
#    'url': 'https://markets.businessinsider.com/news/stocks/ether-burn-ethereum-crypto-upgrade-eip1559-london-hard-fork-price-2021-8',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61168176c040ad0018ce298e?format=jpeg',
#    'publishedAt': '2021-08-15T13:58:48Z',
#    'content': 'The ethereum network runs the ether cryptocurrency, the second-biggest after bitcoin.\r\nDado Ruvic/Reuters\r\nMore than $144 million worth of ether has been burned since an overhaul of the fee system on… [+2126 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Livepeer snags $20M for decentralized video transcoding',
#    'description': 'Livepeer has raised $20 million for its decentralized video transcoding network built on the Ethereum blockchain.',
#    'url': 'https://venturebeat.com/2021/07/29/livepeer-snags-20m-for-decentralized-video-transcoding/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2021/07/livepeer-How-LIvepeer-transcoding-works.jpg?w=1200&strip=all',
#    'publishedAt': '2021-07-29T11:00:02Z',
#    'content': 'All the sessions from Transform 2021 are available on-demand now. Watch now.\r\nLivepeer has raised $20 million for its decentralized video transcoding network built on the Ethereum blockchain.\xa0Its ano… [+6544 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Meet Xoycoin, the Mexican cryptocurrency linked to Ethereum in which you can invest from 20 pesos',
#    'description': 'Xoycoin is the first Mexican cryptocurrency connected to the Ethereum network, its starting price is 8 Mexican pesos (about $ 0.40) and its value is mainly based on sports trading.',
#    'url': 'https://www.entrepreneur.com/article/378430',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627321592-Jul26XoycoinXoyCapitalXYOcriptomonedamexicanaEthereum.jpg',
#    'publishedAt': '2021-07-26T17:46:00Z',
#    'content': 'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nThe firm Xoy Capital , based in Guadalajara, Jalisco, presented Xoycoin , the first … [+3547 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Ethereum's Cryptocurrency Will 'Jettison' Mining for Speedier Proof-of-Stake",
#    'description': '"Ethereum is making big changes," writes Bloomberg. "Perhaps the most important is the jettisoning of the \'miners\' who track and validate transactions on the the world\'s most-used blockchain network.\n\nMiners are the heart of a system known as proof of work. I…',
#    'url': 'https://news.slashdot.org/story/21/08/15/048212/ethereums-cryptocurrency-will-jettison-mining-for-speedier-proof-of-stake',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/money_64.png',
#    'publishedAt': '2021-08-15T10:34:00Z',
#    'content': 'Miners are the heart of a system known as proof of work. It was pioneered by Bitcoin and adopted by Ethereum, and has come under increasing criticism for its environmental impact: Bitcoin miners now … [+1457 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mary Ann Azevedo',
#    'title': 'Shopify allows merchants to sell NFTs directly through their storefronts',
#    'description': 'The NBA’s Chicago Bulls launched its first-ever NFTs –– including digital artwork of NBA championship rings –– by launching an online store on Shopify.',
#    'url': 'http://techcrunch.com/2021/07/27/shopify-now-allowing-imerchants-to-sell-nfts-directly-through-their-storefronts/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/07/Ring-NFT-1993-RINGS.jpg?w=400',
#    'publishedAt': '2021-07-27T16:43:40Z',
#    'content': 'Shopify has made it possible for eligible sellers to sell NFTs (non-fungible tokens) via its platform, which opens up a whole new world for e-commerce merchants.\r\nOn Monday, the NBAs Chicago Bulls la… [+2148 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'rhouston@businessinsider.com (Rickie Houston, CEPF)',
#    'title': 'BlockFi investing review: Trading with no fees or account minimums',
#    'description': 'BlockFi is a global app offering low-cost trading, interest-bearing accounts, crypto-backed loans, and institutional services. See how it works.',
#    'url': 'https://www.businessinsider.com/personal-finance/blockfi-investing-review',
#    'urlToImage': 'https://i.insider.com/60f59bc7bc757c001904ba76?width=1200&format=jpeg',
#    'publishedAt': '2021-07-21T20:24:32Z',
#    'content': 'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5827 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': "PayPal's Venmo allows credit cardholders to buy crypto with cashback - Reuters",
#    'description': 'Paypal Holdings Inc-owned <a href="https://www.reuters.com/companies/PYPL.O" target="_blank">(PYPL.O)</a> Venmo on Tuesday rolled out a feature that would allow holders of its credit cards to automatically buy cryptocurrencies with the cashback earned on thei…',
#    'url': 'https://www.reuters.com/technology/paypals-venmo-allows-credit-cardholders-buy-crypto-with-cashback-2021-08-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/ivbxd2ZWNn2Zfunmxm1y_MlhNRc=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/4VAZ2ZCRTZJ7NHM2LGME3W5SKQ.jpg',
#    'publishedAt': '2021-08-10T16:17:00Z',
#    'content': 'Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 10 (Reuters) - Paypal Holdings Inc-… [+991 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'Bitcoin, cryptos post 5th straight week of outflows -CoinShares data - Reuters',
#    'description': 'Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scrutiny, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/article/legal-us-fintech-crypto-flows-idUSKBN2FB1DO',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210810&t=2&i=1571521012&r=LYNXMPEH790MV&w=800',
#    'publishedAt': '2021-08-10T14:19:00Z',
#    'content': 'NEW YORK (Reuters) - Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scruti… [+2022 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Bitcoin, cryptos post 5th straight week of outflows -CoinShares data - Reuters',
#    'description': 'Bitcoin investment products and funds registered outflows for a fifth consecutive week, as investor sentiment remained cautious in the midst of increased global regulatory scrutiny, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/technology/bitcoin-cryptos-post-5th-straight-week-outflows-coinshares-data-2021-08-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/_5lTYPm4R5fFav9Ag5rmRlahRis=/800x419/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7YZMDMXDOVMOZNMBSLVCED2KEU.jpg',
#    'publishedAt': '2021-08-09T20:21:00Z',
#    'content': 'A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, Aug 9 (Reuters) - Bitcoin investment products and funds register… [+2160 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin rises 7.07% to $47587.38 - Reuters',
#    'description': 'Bitcoin  surged 7.07% to $47,587.38 at 2200 GMT on Friday, adding $3,142.93 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-707-4758738-2021-08-13/',
#    'urlToImage': 'https://www.reuters.com/resizer/LcnGvi5sh8VWWqo7vm6NoHwCDOQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/F32JNXDLTRP7BJ4YAY7XD3QIEE.jpg',
#    'publishedAt': '2021-08-13T22:14:00Z',
#    'content': 'Representations of cryptocurrency Bitcoin are seen in this picture illustration taken June 7, 2021. REUTERS/Edgar Su/IllustrationAug 13 (Reuters) - Bitcoin surged 7.07% to $47,587.38 at 2200 GMT on F… [+418 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Cross-Chain DeFi Site Poly Network Hacked; Hundreds of Millions Potentially Lost',
#    'description': 'Cross-chain decentralized finance (DeFi) platform Poly Network was attacked on Tuesday, with the alleged hacker draining roughly $600 million in crypto. From a report: Poly Network, a protocol launched by the founder of Chinese blockchain project Neo, operate…',
#    'url': 'https://it.slashdot.org/story/21/08/10/1757226/cross-chain-defi-site-poly-network-hacked-hundreds-of-millions-potentially-lost',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/security_64.png',
#    'publishedAt': '2021-08-10T18:05:00Z',
#    'content': "Poly Network, a protocol launched by the founder of Chinese blockchain project Neo, operates on the Binance Smart Chain, Ethereum and Polygon blockchains. Tuesday's attack struck each chain consecuti… [+888 chars]"},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Polygon Studio will offer $100M to fund gaming NFT projects',
#    'description': 'Polygon has set up a $100 million fund for projects aimed at combining the hot blockchain technology with gaming.',
#    'url': 'https://venturebeat.com/2021/07/20/polygon-studio-will-offer-100m-to-fund-gaming-nft-projects/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2021/07/polygon.jpg?w=1200&strip=all',
#    'publishedAt': '2021-07-20T12:30:18Z',
#    'content': 'All the sessions from Transform 2021 are available on-demand now. Watch now.\r\nPolygon, a maker of a crypto-based platform for nonfungible tokens (NFTs), has set up a $100 million fund for projects ai… [+8080 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss,Michelle Price',
#    'title': 'Explainer: How hackers stole $613 million in crypto tokens from Poly Network - Reuters',
#    'description': 'Hackers pulled off the biggest ever cryptocurrency heist on Tuesday, stealing $613 million in digital coins from token-swapping platform Poly Network, <a href="https://www.reuters.com/technology/defi-platform-poly-network-reports-hacking-loses-estimated-600-m…',
#    'url': 'https://www.reuters.com/technology/how-hackers-stole-613-million-crypto-tokens-poly-network-2021-08-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/nOykOK32OOyyi1mrHqq1d5oQTFg=/800x419/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QFXJ5BZKJZKTJMDH65JS52NMLY.jpg',
#    'publishedAt': '2021-08-12T04:17:00Z',
#    'content': 'WASHINGTON, Aug 12 (Reuters) - Hackers pulled off the biggest ever cryptocurrency heist on Tuesday, stealing $613 million in digital coins from token-swapping platform Poly Network, only to return $2… [+4029 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss, Michelle Price',
#    'title': 'Explainer-How hackers stole $613 million in crypto tokens from Poly Network - Reuters',
#    'description': 'Hackers pulled off the biggest ever cryptocurrency heist on Tuesday, stealing $613 million in digital coins from token-swapping platform Poly Network, only to return $260 million https://www.reuters.com/technology/defi-platform-poly-network-reports-hacking-lo…',
#    'url': 'https://www.reuters.com/article/us-fintech-blockchain-polynetwork-cyber-idUSKBN2FD09P',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210812&t=2&i=1571688053&r=LYNXMPEH7B048&w=800',
#    'publishedAt': '2021-08-12T04:02:00Z',
#    'content': 'WASHINGTON (Reuters) - Hackers pulled off the biggest ever cryptocurrency heist on Tuesday, stealing $613 million in digital coins from token-swapping platform Poly Network, only to return $260 milli… [+4020 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': "Tesla will 'most likely' restart accepting bitcoin as payments, says Musk - Reuters",
#    'description': 'Electric-car maker Tesla Inc <a href="https://www.reuters.com/companies/TSLA.O" target="_blank">(TSLA.O)</a> will most likely restart accepting bitcoin as payments, Chief Executive Officer Elon Musk said at a conference on Wednesday.',
#    'url': 'https://www.reuters.com/business/autos-transportation/tesla-will-most-likely-restart-accepting-bitcoin-payments-says-musk-2021-07-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/-IbAMiIDsvmSmvucUTS-TEVNc8U=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HJLMO2EG3BPODPG2Y2UNPAPOKY.jpg',
#    'publishedAt': '2021-07-21T18:53:00Z',
#    'content': 'Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Tether executives said to face criminal probe into bank fraud - Bloomberg News - Reuters',
#    'description': 'The U.S. Department of Justice is probing whether executives behind the Tether digital token committed bank fraud during the nascent stages of its cryptocurrency business, Bloomberg News reported on Monday',
#    'url': 'https://www.reuters.com/article/us-tether-probe-doj-idUSKBN2EW1OB',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210726&t=2&i=1569996220&r=LYNXMPEH6P10B&w=800',
#    'publishedAt': '2021-07-26T14:01:00Z',
#    'content': 'By Reuters Staff\r\nA representation of the virtual cryptocurrency Ethereum is seen among representations of other cryptocurrencies in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Il… [+852 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Crypto sector sees outflows for 4th week in a row, CoinShares data shows - Reuters',
#    'description': 'Cryptocurrency investment products and funds posted outflows for a fourth consecutive week, the bulk of which came from bitcoin products, which also experienced its fourth straight weekly outflow, data from digital asset manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/business/finance/crypto-sector-sees-outflows-4th-week-row-coinshares-data-shows-2021-08-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/lmbIm3yyzD-3zaKlFvxHzYrSWHw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KEMQM7X26VP4DOPR5PQ5ODM4HY.jpg',
#    'publishedAt': '2021-08-02T20:10:00Z',
#    'content': 'A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Illustration/FilesNEW YORK, Aug 2 (Reuters) - Cryptocurrency investme… [+2265 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Carla Mozée)',
#    'title': 'NFT auction site OpenSea reaches $1.5 billion valuation after latest funding round raises $100 million',
#    'description': 'Venture capital firm Andreessen Horowitz has led two rounds of fundraising for NFT marketplace OpenSea.',
#    'url': 'https://markets.businessinsider.com/currencies/news/nft-auction-site-opensea-billion-valuation-crypto-unicorn-digital-artwork-2021-7',
#    'urlToImage': 'https://images2.markets.businessinsider.com/60f6d7529addaf00191eaf37?format=jpeg',
#    'publishedAt': '2021-07-20T15:31:16Z',
#    'content': 'Chung Sung-Jun/Getty Images\r\nOpenSea, a marketplace for digital collectibles, hit a valuation of $1.5 billion in its latest round of fundraising, according to reports, highlighting bullishness in the… [+1909 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mat Smith',
#    'title': 'The Morning After: Samsung unveils a more durable Galaxy Z Fold 3 with S Pen support',
#    'description': 'I’m not sold on foldable phones. They’re expensive, have questionable durability and — at least so far — don’t offer a compelling reason for the form factor. Having said all that, the Galaxy Z Flip 3, Samsung’s new clamshell foldable, is almost enough to chan…',
#    'url': 'https://www.engadget.com/the-morning-after-samsung-galaxy-z-fold-3-flip-3-113019765.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-08/8be12a70-fb5a-11eb-8fff-b89ed8c15711',
#    'publishedAt': '2021-08-12T11:15:19Z',
#    'content': 'Im not sold on foldable phones. Theyre expensive, have questionable durability and at least so far dont offer a compelling reason for the form factor. Having said all that, the Galaxy Z Flip 3, Samsu… [+5257 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ilee@insider.com (Isabelle Lee)',
#    'title': 'US stocks edge higher as fall in weekly jobless claims eases labor-market concerns',
#    'description': 'US stocks regained some ground Thursday after a selloff the prior session driven by lackluster private payroll data.',
#    'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-today-jobless-claims-hiring-economy-dow-sp500-2021-8',
#    'urlToImage': 'https://images2.markets.businessinsider.com/6087d3b40da8f40018033a24?format=jpeg',
#    'publishedAt': '2021-08-05T13:41:15Z',
#    'content': 'Spencer Platt/Getty Images\r\nUS stocks trade higher on Thursday as a fall in weekly jobless claims eased labor-market concerns.\r\nThe number of Americans filing for unemployment benefits dropped less t… [+2003 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Chloe Arrojado',
#    'title': "Want to Buy a Franchise, But Don't Have the Cash? This Company Wants You to Buy In With Crypto.",
#    'description': 'Florida-based moving franchise College Hunks is hoping to cash in on alternative payment methods.',
#    'url': 'https://www.entrepreneur.com/article/376592',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1625855303-college-hunks-Nick-Friedman-and-Omar-Soliman.jpg',
#    'publishedAt': '2021-07-15T17:00:00Z',
#    'content': 'College Hunks’\xa0first franchisee didn’t have enough cash to pay a franchise fee, but he did have land.\r\nThat’s who Nick Friedman, co-founder of moving company College Hunks, credits for sending the co… [+5516 chars]'},
#   {'source': {'id': None, 'name': 'Protos.com'},
#    'author': None,
#    'title': 'Ethereum dev Virgil Griffith back in jail after checking $1M Coinbase account',
#    'description': 'Indicted Ethereum developer Virgil Griffith is back to jail after allegedly breaching bail conditions by checking his Coinbase balance.',
#    'url': 'https://protos.com/griffith-virgil-coinbase-account-ethereum-jail-north-korea-arrest/',
#    'urlToImage': 'https://protos.com/wp-content/uploads/2021/07/Protos-Artwork-GriffithJail.jpg',
#    'publishedAt': '2021-07-23T07:18:52Z',
#    'content': 'Indicted Ethereum Foundation developer Virgil Griffith is headed back to jail to await another day in court after a judge ruled he breached bail conditions by accessing his Coinbase account, reports … [+1889 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'htowey@insider.com (Hannah Towey)',
#    'title': 'CryptoPunks: pixelated avatars that the wealthy are snapping up for millions of dollars',
#    'description': "These 10,000 digital characters are now worth almost $400 million. See the 'Covid Alien' that sold for $11.7 million and other rare CryptoPunks.",
#    'url': 'https://www.businessinsider.com/cryptopunks-pixelated-avatars-that-millionaires-buy-nft-2021-7',
#    'urlToImage': 'https://i.insider.com/60f1ad4271757b0018c6a071?width=1200&format=jpeg',
#    'publishedAt': '2021-07-16T18:23:30Z',
#    'content': 'These pixelated avatars, known as "CryptoPunks," were first released in 2017 by creators Matt Hall and John Watkinson as an experiment. The characters, initially available for free, are now being auc… [+793 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'You can now pay with Dogecoin in Coinbase Commerce, we tell you how it works',
#    'description': 'Elon Musk likes this. Dogecoin became the seventh cryptocurrency accepted as a form of payment on Coinbase Commerce, the e-commerce platform of the US exchange.',
#    'url': 'https://www.entrepreneur.com/article/378285',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627068481-Jul23YapuedespagarconDogecoinenCoinbaseCommerceF1.jpg',
#    'publishedAt': '2021-07-23T19:28:00Z',
#    'content': 'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nThe e-commerce platform Coinbase Commerce , announced that from now on you can pay f… [+2103 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Ariel Shapira',
#    'title': 'What the Most Recent Crypto Bull Run Means for DeFi',
#    'description': "As crypto's popularity continues to surge, the opportunities are endless.",
#    'url': 'https://www.entrepreneur.com/article/377830',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627050276-shutterstock-1976868902.jpg',
#    'publishedAt': '2021-07-27T13:15:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nFrom a late December pickup to the end of the rally in mid-April, Bitcoin sprung up by over 230%. And then with one announcement, it wa… [+7213 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Jennifer Atkinson',
#    'title': 'How to Create a Non-Fungible Token? [Ultimate Guide]',
#    'description': 'The world of Non-Fungible Tokens (NFTs) offers a golden opportunity for entrepreneurs to maximize the traction of their business. They have a soaring market capitalization of $22.25 billion and a daily trading volume of $2.68 billion, according to CoinMarketC…',
#    'url': 'https://readwrite.com/2021/07/24/how-to-create-a-non-fungible-token-ultimate-guide/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2021/05/How-to-Create-a-Non-Fungible-Token-Ultimate-Guide.jpg',
#    'publishedAt': '2021-07-24T14:01:03Z',
#    'content': 'The world of Non-Fungible Tokens (NFTs) offers a golden opportunity for entrepreneurs to maximize the traction of their business. They have a soaring market capitalization of $22.25 billion and a dai… [+9406 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Tether executives said to face criminal probe into bank fraud - Bloomberg News - Reuters',
#    'description': 'The U.S. Department of Justice is probing whether executives behind the Tether digital token committed bank fraud during the nascent stages of its cryptocurrency business, Bloomberg News reported on Monday',
#    'url': 'https://www.reuters.com/business/finance/tether-executives-said-face-criminal-probe-into-bank-fraud-bloomberg-news-2021-07-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/InHvCiSZm4U-VU8bDnCg_6ScF8s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/UGHMBKNQAJIUNAN7OCRGXCKYOM.jpg',
#    'publishedAt': '2021-07-26T14:10:00Z',
#    'content': 'A representation of the virtual cryptocurrency Ethereum is seen among representations of other cryptocurrencies in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/IllustrationJuly 26 … [+995 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 1-Crypto firm FTX Trading raises $900 mln at $18 bln valuation - Reuters',
#    'description': 'FTX Trading Ltd said on Tuesday it had raised $900 million from investors including SoftBank Group Corp and Sequoia in a funding round that valued the owner of the FTX.COM cryptocurrency exchange at $18 billion.',
#    'url': 'https://www.reuters.com/article/us-ftx-funding-idUSKBN2EQ1XK',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210720&t=2&i=1569434240&r=LYNXMPEH6J11O&w=800',
#    'publishedAt': '2021-07-20T17:27:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ru… [+1062 chars]'},
#   {'source': {'id': None, 'name': 'Avc.com'},
#    'author': 'Fred Wilson',
#    'title': 'Funding Friday: Ethereum: The Infinite Garden',
#    'description': 'ETHEREUM: THE INFINITE GARDEN is a “feature-length documentary film that explores the innovative real-world applications of the Ethereum blockchain, the die-hard community of enthusiasts and developers, and its creator, Vitalik Buterin, whose vision for the i…',
#    'url': 'https://avc.com/2021/07/funding-friday-ethereum-the-infinite-garden/',
#    'urlToImage': 'https://avc.com/content/uploads/2021/07/Screen-Shot-2021-07-16-at-7.14.35-AM.png',
#    'publishedAt': '2021-07-16T11:23:51Z',
#    'content': 'ETHEREUM: THE INFINITE GARDEN is a “feature-length documentary film that explores the innovative real-world applications of the Ethereum blockchain, the die-hard community of enthusiasts and develope… [+522 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Ivan Mehta',
#    'title': 'Hacker who stole $600M of crypto returns $260M… ’cos they don’t dig money?',
#    'description': 'Hackers stealing cryptocurrency is a regular event in the last couple of years. But in a bizarre incident, a hacker who stole $600 million worth of cryptocurrency earlier this week, returned $260 million of them. Here’s what happened. A hacker took advantage …',
#    'url': 'https://thenextweb.com/news/hacker-stole-600m-crypto-returns-260m',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2021%2F08%2FMaxPixel.net-Cryptocurrency-Money-Ethereum-Eth-Coin-Digital-6286123-e1628755636840.jpg&signature=25a65b9f4598edc88945629c7faf401f',
#    'publishedAt': '2021-08-12T11:07:18Z',
#    'content': 'Hackers stealing cryptocurrency is a regularevent in the last couple of years. But in a bizarre incident, a hacker who stole $600 million worth of cryptocurrency earlier this week, returned $260 mill… [+1809 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Reuters in New York and London',
#    'title': '‘White hat’ hacker behind $610m crypto heist returns most of money',
#    'description': 'About $33m in frozen coins yet to be returned as still-unidentified hacker claims attack was carried out ‘for fun’ to ‘expose the vulnerability’ of platformHackers behind one of the biggest-ever digital coin heists have now returned nearly all of the $610m-pl…',
#    'url': 'https://amp.theguardian.com/technology/2021/aug/13/white-hat-hacker-behind-610m-crypto-heist-returns-most-of-money',
#    'urlToImage': 'https://i.guim.co.uk/img/media/14497a5958db93459ccc506a6a1a4849658c4fdc/0_267_4000_2400/master/4000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=bf81e7c37f6d308892eb16a3f90d0b9e',
#    'publishedAt': '2021-08-13T02:04:39Z',
#    'content': 'Hackers behind one of the biggest-ever digital coin heists have now returned nearly all of the $610m-plus they stole, the cryptocurrency platform targeted this week by the attack says.\r\nThe Poly Netw… [+2672 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Tim Ogilvie',
#    'title': 'Outside the Box: Ethereum, the No. 2 behind bitcoin, fights off challengers that offer cheaper and faster blockchains',
#    'description': 'Ethereum, known for its "smart" contracts, is bested in security, scalability and energy consumption.',
#    'url': 'https://www.marketwatch.com/story/ethereum-the-no-2-behind-bitcoin-fights-off-challengers-that-offer-cheaper-and-faster-blockchains-11627058363',
#    'urlToImage': 'https://images.mktw.net/im-337837/social',
#    'publishedAt': '2021-07-23T16:39:00Z',
#    'content': 'If you are an investor who dabbles in cryptocurrencies, or even are what we in the industry call crypto-curious, you know ethereum \r\n ETHUSD,\r\n +0.23%\r\nas the No. 2 cryptocurrency behind bitcoin \r\n B… [+7731 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'rhouston@businessinsider.com (Rickie Houston, CEPF)',
#    'title': 'Kraken versus Coinbase: How the crypto exchanges compare',
#    'description': "Kraken and Coinbase both offer 50+ cryptocurrencies, staking rewards, and institutional services, but the crypto exchanges' fees and features vary.",
#    'url': 'https://www.businessinsider.com/personal-finance/kraken-vs-coinbase-crypto-exchange-comparison',
#    'urlToImage': 'https://i.insider.com/6116c6b23dd01000199da9df?width=1200&format=jpeg',
#    'publishedAt': '2021-08-13T20:10:40Z',
#    'content': 'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+7016 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': "Crypto firm FTX Trading's valuation rises to $18 bln after $900 mln investment - Reuters",
#    'description': 'FTX Trading Ltd said on Tuesday its valuation had risen to $18 billion after a $900 million funding round that included SoftBank Group Corp <a href="https://www.reuters.com/companies/9984.T" target="_blank">(9984.T)</a> and was one of the biggest fundraises f…',
#    'url': 'https://www.reuters.com/technology/crypto-firm-ftx-trading-raises-900-mln-18-bln-valuation-2021-07-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/ueJtkjyeNWawC2EeRlrxZljHXpM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6UVNR3WPMRJC3G7S6WGOMPMYNE.jpg',
#    'publishedAt': '2021-07-20T18:30:00Z',
#    'content': 'Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationJuly 20 (Reute… [+1909 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Mervik Haums',
#    'title': '5 Reasons to Get Started With DeFi',
#    'description': 'DeFi creates a banking system that is open to all, decentralized, transparent and secure.',
#    'url': 'https://www.entrepreneur.com/article/377675',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1626792154-shutterstock-1880148124.jpg',
#    'publishedAt': '2021-07-27T13:30:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nFrom giants like Tesla, Square and\xa0Microstrategy to small-scale traders, everyone is betting on blockchain projects. And why not? Withi… [+7085 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Tom Wilson',
#    'title': "UPDATE 1-Binance stops selling 'stock tokens' after regulatory scrutiny - Reuters",
#    'description': 'Major cryptocurrency exchange Binance said on Friday that users can no longer buy digital tokens linked to stocks, a day after Italian regulators joined a string of financial watchdogs to crackdown on the platform',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-binance-idUSKBN2EM114',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210716&t=2&i=1569060866&r=LYNXMPEH6F0GW&w=800',
#    'publishedAt': '2021-07-16T10:33:00Z',
#    'content': 'FILE PHOTO: Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, and Litecoin are seen in front of a displayed Binance logo in this illustration taken, June 28, 2021. REUTERS/Dado… [+1465 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Thomas Borrel',
#    'title': 'Why Energy Concerns Around Blockchain May Be a Misconception',
#    'description': "For those concerned about blockchain's energy consumption, it's important to consider the difference between proof-of-stake and proof-of-work blockchains.",
#    'url': 'https://www.entrepreneur.com/article/375742',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1626887066-shutterstock-749922058.jpg',
#    'publishedAt': '2021-07-25T12:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nFor business leaders that are on the fence about whether their company should use blockchain, conversations around blockchain’s energy … [+5531 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Amazon denies that it will accept bitcoin as a form of payment',
#    'description': 'The company says the information in the City Am article is false and they will not accept cryptocurrencies this year.',
#    'url': 'https://www.entrepreneur.com/article/378561',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1627410181-amazon1.jpg',
#    'publishedAt': '2021-07-27T18:23:18Z',
#    'content': 'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nLast week, Amazon ran an ad saying it was looking for a cryptocurrency expert withou… [+1164 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'The Conversation',
#    'title': 'Everything you need to know about stablecoins',
#    'description': 'Stablecoins are a type of cryptocurrency linked to an asset like the U.S. dollar that doesn’t change much in value. The majority of the dozens of stablecoins that currently exist use the dollar as their benchmark asset, but many are also pegged to other fiat …',
#    'url': 'https://thenextweb.com/news/everything-need-know-stablecoins-syndication',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2021%2F07%2FStablecoin-Tether-hed-drawkit-illustrations-5xlHjrzQO54-unsplash.jpg&signature=ecca4edff107eec2e734c5ee26467bae',
#    'publishedAt': '2021-08-01T10:00:26Z',
#    'content': 'Stablecoins are a type of cryptocurrency linked to an asset like the U.S. dollar that doesnt change much in value.\r\nThe majority of the dozens of stablecoins that currently exist use the dollar as th… [+2913 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "Elon Musk says Tesla's caused him two-thirds of the personal and professional pain he's ever felt",
#    'description': '"This is a hella hard situation," Musk told Twitter CEO Jack Dorsey in a chat about bitcoin on Wednesday.',
#    'url': 'https://www.businessinsider.com/elon-musk-two-thirds-personal-professional-pain-tesla-2021-7',
#    'urlToImage': 'https://i.insider.com/60f870b30729770012b92177?width=1200&format=jpeg',
#    'publishedAt': '2021-07-21T19:47:43Z',
#    'content': 'Elon Musk said two-thirds of the "personal and professional pain" he\'s experienced has stemmed from running Tesla.\xa0\r\nIn a virtual bitcoin conference with Twitter CEO Jack Dorsey, Musk who\'s also CEO … [+1574 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jonathan Stempel',
#    'title': 'New Jersey orders BlockFi cryptocurrency firm to stop offering interest-bearing accounts - Reuters',
#    'description': "New Jersey ordered the cryptocurrency platform BlockFi Inc to stop offering interest-bearing accounts that have raised $14.7 billion from investors, the state's acting attorney general said on Tuesday.",
# ...
#    'url': 'https://www.reuters.com/world/china/global-markets-wrapup-2-2021-08-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/369mpgp_IFWwDGT4TFZ3p7W0u-o=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/4IGJKJEO4VJULGFPX3EDXM55WY.jpg',
#    'publishedAt': '2021-08-06T06:15:00Z',
#    'content': 'Investors sit in front of a board showing stock information at a brokerage house on the first day of trade in China since the Lunar New Year, in Hangzhou, Zhejiang province, China February 3, 2020. C… [+3673 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Hideyuki Sano',
#    'title': 'Dollar holds firm near 4-month high, retains weekly gains on Fed bets - Reuters',
#    'description': 'The dollar held firm on Friday, staying near its highest level in four months against a basket of currencies as investors looked for more hints from the Federal Reserve on its plans to reduce monetary stimulus.',
#    'url': 'https://www.reuters.com/world/middle-east/dollar-holds-firm-near-4-month-high-retains-weekly-gains-fed-bets-2021-08-13/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=49',
#    'publishedAt': '2021-08-13T03:39:00Z',
#    'content': 'TOKYO, Aug 13 (Reuters) - The dollar held firm on Friday, staying near its highest level in four months against a basket of currencies as investors looked for more hints from the Federal Reserve on i… [+3489 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Simon Jessop',
#    'title': 'World shares ride earnings to fresh high, dollar steady - Reuters',
#    'description': "Global shares were driven by strong earnings to a record high on Wednesday, while the dollar and Treasury yields languished waiting for U.S. employment data to provide clues about the pace of monetary tightening in the world's biggest economy.",
#    'url': 'https://www.reuters.com/business/global-markets-wrapup-5-pix-2021-08-04/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=48',
#    'publishedAt': '2021-08-04T11:17:00Z',
#    'content': 'LONDON, Aug 4 (Reuters) - Global shares were driven by strong earnings to a record high on Wednesday, while the dollar and Treasury yields languished waiting for U.S. employment data to provide clues… [+3328 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Alun John',
#    'title': 'GLOBAL MARKETS-Asian stocks hold gains, dollar strong on Fed official comments - Reuters',
#    'description': 'Asian shares held on to recent gains in morning trading on Thursday, despite hawkish remarks from a senior official at the U.S. Federal Reserve, that boosted the dollar while weighing on risk appetite, and uncertainty about Chinese policy.',
#    'url': 'https://www.reuters.com/article/uk-global-markets-idUSKBN2F6075',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210805&t=2&i=1571019410&r=LYNXMPEH7402O&w=800',
#    'publishedAt': '2021-08-05T02:13:00Z',
#    'content': 'HONG KONG (Reuters) - Asian shares held on to recent gains in morning trading on Thursday, despite hawkish remarks from a senior official at the U.S. Federal Reserve, that boosted the dollar while we… [+3026 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Alun John',
#    'title': "Asian stocks hold gains, dollar strong on Fed official's comments - Reuters",
#    'description': "Asian shares mostly held onto this week's gains on Thursday, despite hawkish remarks from a senior official at the U.S. Federal Reserve that boosted the dollar while weighing on risk appetite.",
#    'url': 'https://www.reuters.com/world/china/global-markets-wrapup-2-2021-08-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/l1kGnFrC9BMZtBLBnWRLFWM6wqY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/IPK2GMXW2JKS7OQRIBBSO6IPTU.jpg',
#    'publishedAt': '2021-08-05T05:53:00Z',
#    'content': 'An investor looks at an electronic board showing stock information at a brokerage house in Beijing, August 27, 2015. REUTERS/Jason Lee/File PhotoHONG KONG, Aug 5 (Reuters) - Asian shares mostly held … [+3751 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lawrence White, Alun John',
#    'title': 'GLOBAL MARKETS-Markets eye US jobs report as stocks, FX dip on delta blues - Reuters',
#    'description': 'Stocks and emerging markets currencies edged down on Friday and oil headed for its biggest weekly loss since March, as nervousness over the spread of the COVID-19 Delta variant hit risk assets and crimped demand.',
#    'url': 'https://www.reuters.com/article/global-markets-idUSL1N2PD0H7',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-08-06T08:04:00Z',
#    'content': '* European, Asian shares fall 0.1%\r\n* Thai baht leads FX falls on rising Delta cases\r\n* U.S. jobs report due 1230 GMT, hoped to be robust\r\nLONDON/HONG KONG, Aug 6 (Reuters) - Stocks and emerging mark… [+2950 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lawrence White,Alun John',
#    'title': 'Markets eye US jobs report as stocks, FX dip on delta blues - Reuters',
#    'description': 'Stocks and emerging markets currencies edged down on Friday and oil headed for its biggest weekly loss since March, as nervousness over the spread of the COVID-19 Delta variant hit risk assets and crimped demand.',
#    'url': 'https://www.reuters.com/world/china/global-markets-wrapup-3-pix-2021-08-06/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=48',
#    'publishedAt': '2021-08-06T08:08:00Z',
#    'content': 'LONDON/HONG KONG, Aug 6 (Reuters) - Stocks and emerging markets currencies edged down on Friday and oil headed for its biggest weekly loss since March, as nervousness over the spread of the COVID-19 … [+3029 chars]'},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': "CryptoPunk Prices See 53% Increase After Ethereum Whales' Purchase Frenzy",
#    'description': "CryptoPunks have seen a resurgence once again after this weekend's Ethereum whale frenzy. HYPEBEAST recently reported that a single Ethereum whale has driven up the price of CryptoPunks by shelling out $6 million USD on one CryptoPunk NFT.Thanks to the sudden…",
#    'url': 'https://hypebeast.com/2021/8/cryptopunk-price-rises-after-ethereum-whales-purchase-frenzy',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2021%2F08%2Fcryptopunk-price-rises-after-ethereum-whales-purchase-frenzy-tw.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2021-08-02T04:16:41Z',
#    'content': 'CryptoPunks have seen a resurgence once again after this weekend’s Ethereum whale frenzy. HYPEBEAST recently reported that a single Ethereum whale has driven up the price of CryptoPunks by shelling o… [+1318 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Mike Murphy',
#    'title': 'Crypto: Bitcoin rally meets resistance as price approaches its 200-day moving average',
#    'description': 'Bitcoin rallied as high as $44,575 on Sunday -- almost hitting its 200-day moving average of $44,600 -- before slipping.',
#    'url': 'https://www.marketwatch.com/story/bitcoin-rally-meets-resistance-as-price-approaches-its-200-day-moving-average-11628467797',
#    'urlToImage': 'https://images.mktw.net/im-360625/social',
#    'publishedAt': '2021-08-09T00:09:00Z',
#    'content': 'The price of bitcoin met resistance as it closed in on its 200-day moving average Sunday.Bitcoin \r\n BTCUSD,\r\n -1.09%\r\nrallied as high as $44,575 early Sunday almost hitting its 200-day moving average… [+1094 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'MarketWatch',
#    'title': 'NewsWatch: Dow clears 35,000 milestone on Friday on 6th try',
#    'description': 'The sixth time is a charm for the Dow Jones Industrial Average, closing above 35,000 for the first time Friday, as stocks cap a buy-the-dip rebound from a selloff that opened the week.',
#    'url': 'https://www.marketwatch.com/story/dow-clears-35000-milestone-on-friday-on-6th-try-2021-07-25',
#    'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#    'publishedAt': '2021-07-25T13:00:06Z',
#    'content': 'The sixth time is a charm for the Dow Jones Industrial Average, closing above 35,000 for the first time Friday, as stocks cap a buy-the-dip rebound from a selloff that opened the week. See full story… [+1072 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'MarketWatch',
#    'title': 'NewsWatch: Dow clears 35,000 milestone on Friday on 6th try',
#    'description': 'The sixth time is a charm for the Dow Jones Industrial Average, closing above 35,000 for the first time Friday, as stocks cap a buy-the-dip rebound from a selloff that opened the week.',
#    'url': 'https://www.marketwatch.com/story/dow-clears-35000-milestone-on-friday-on-6th-try-2021-07-24-1710305',
#    'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#    'publishedAt': '2021-07-24T21:00:05Z',
#    'content': 'The sixth time is a charm for the Dow Jones Industrial Average, closing above 35,000 for the first time Friday, as stocks cap a buy-the-dip rebound from a selloff that opened the week. See full story… [+1072 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (William Gallagher)',
#    'title': 'Cryptocurrency platform Poly Network hack steals $600 million',
#    'description': 'Poly Network, the cryptocurrency interoperability protocol, says that it has been hacked and more than $600 million in assorted cryptocurrency was stolen.While individuals have attempted various cryptocurrency related scams, now the Poly Network has taken to …',
#    'url': 'https://appleinsider.com/articles/21/08/11/cryptocurrency-platform-poly-network-hack-steals-600-million',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/43394-84331-bitcoin-pile-xl.jpg',
#    'publishedAt': '2021-08-11T10:46:37Z',
#    'content': 'Poly Network, the cryptocurrency interoperability protocol, says that it has been hacked and more than $600 million in assorted cryptocurrency was stolen. \r\nWhile individuals have attempted various c… [+1082 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': '10 things before the opening bell',
#    'description': 'Moderna spikes, US Binance head is out, Tesla may surge.',
#    'url': 'https://www.businessinsider.com/10-things-before-the-opening-bell-august-10-2021-8',
#    'urlToImage': 'https://images2.markets.businessinsider.com/61119eabdaba4e0019e5a930?format=jpeg',
#    'publishedAt': '2021-08-10T10:01:38Z',
#    'content': 'People walk past the New York Stock Exchange (NYSE) on Wall Street on July 15, 2021 in New York City.\r\nAngela Weiss/AFP/Getty Images\r\nWelcome to 10 Things Before the Opening Bell. \r\nIf this was forwa… [+2951 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': '10 things before the opening bell',
#    'description': 'Jobless claims on the rise, space tourism, and the lumber market.',
#    'url': 'https://www.businessinsider.com/10-things-before-the-opening-bell-july-23-2021-7',
#    'urlToImage': 'https://i.insider.com/60f9d61afc253600181ff149?width=1200&format=jpeg',
#    'publishedAt': '2021-07-23T10:39:03Z',
#    'content': "Welcome to 10 Things Before the Opening Bell.\xa0\xa0\r\nIf this was forwarded to you, sign up here. Plus, sign up here for Insider Investing, our weekly markets analysis newsletter.\r\nLet's get into it.\r\n1.\xa0… [+2576 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ddavis@businessinsider.com (Dominic-Madori Davis)',
#    'title': "The 24-year-old founder of an NFT art gallery raised $7.6 million in funds on his quest to create the 'Instagram for NFTs'",
#    'description': 'Showtime is a platform where users discover and browse digital art collections, giving NFTs the "social aspect it was missing before."',
#    'url': 'https://www.businessinsider.com/meet-alex-masmej-founder-nft-art-gallery-showtime-2021-8',
#    'urlToImage': 'https://i.insider.com/611130702a24d000186258bb?width=1200&format=jpeg',
#    'publishedAt': '2021-08-10T16:08:55Z',
#    'content': "Name: Alex Masmej\r\nAge: 24\r\nLocation: San Francisco, California\xa0\r\nBusiness: It's an NFT world and we're all just living in it. The NFT market topped $2 billion in sales this year and its art sector g… [+3272 chars]"},
#   {'source': {'id': 'vice-news', 'name': 'Vice News'},
#    'author': 'Ekin Genç, Jordan Pearson',
#    'title': "The Future of Cryptocurrency Is Being Decided in Biden's Infrastructure Bill",
#    'description': "A small part of the bill concerning cryptocurrency tax reporting requirements has turned into a massive fight, with the industry's future on the line.",
#    'url': 'https://www.vice.com/en/article/bvzbmw/the-future-of-cryptocurrency-is-being-decided-in-bidens-infrastructure-bill',
#    'urlToImage': 'https://video-images.vice.com/articles/610d908bedaf330093898768/lede/1628279593113-gettyimages-1234491289.jpeg?image-resize-opts=Y3JvcD0xeHc6MC44NDI1eGg7MHh3LDAuMDQwNnhoJnJlc2l6ZT0xMjAwOiomcmVzaXplPTEyMDA6Kg',
#    'publishedAt': '2021-08-06T19:56:24Z',
#    'content': 'Two competing amendments to the Senate’s infrastructure bill may shape the future of cryptocurrency in the United States as senators fight over who must be subject to new tax reporting requirements.\r… [+5406 chars]'},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': 'A New Documentary About the Future of Crypto Is in the Works',
#    'description': "Optimist — the film company backing GameStop's working-titled\xa0The Meme Economy — will officially begin production on a cryptocurrency documentary, titled\xa0Ethereum: The Infinite Garden, after financing the film in only two days, according to Deadline.In just o…",
#    'url': 'https://hypebeast.com/2021/7/optimist-documentary-ethereum-blockchain-funding-production',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2021%2F07%2FA-New-Documentary-About-the-Future-of-Crypto-Is-in-the-Works-TW.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2021-07-21T21:15:55Z',
#    'content': 'Optimist the film company backing GameStop‘s working-titled\xa0The Meme Economy will officially begin production on a cryptocurrency documentary, titled\xa0Ethereum: The Infinite Garden, after financing th… [+1462 chars]'},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': 'A Single Ethereum Whale Has Spent $6 Million USD on CryptoPunk NFTs',
#    'description': 'An Ethereum whale has spent $6 million USD on purchasing CryptoPunks.According to new reports, the single buyer has now accumulated more than one percent of the entire CryptoPunks collection, a limited series of 10,000 non-fungible tokens with an extremely ac…',
#    'url': 'https://hypebeast.com/2021/8/cryptopunk-nfts-ethereum-whale-6-million-usd-purchases',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2021%2F08%2Fcryptopunk-nfts-ethereum-whale-6-million-usd-purchases-tw.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2021-08-01T06:29:14Z',
#    'content': 'An Ethereum whale has spent $6 million USD on purchasing CryptoPunks.\r\nAccording to new reports, the single buyer has now accumulated more than one percent of the entire CryptoPunks collection, a lim… [+669 chars]'}]}

# %%
btc_all_articles["articles"][0]
# Out:
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Paul Ford',
#  'title': 'A Field Guide for Nature-Resistant Nerds',
#  'description': 'Yes, yes, the dirt is horrifying. But it’s also how we make bitcoin apps.',
#  'url': 'https://www.wired.com/story/a-field-guide-for-nature-resistant-nerds-microchips-climate-change/',
#  'urlToImage': 'https://media.wired.com/photos/61086c497b8c62be3062fe82/191:100/w_1280,c_limit/WI090121_MG_Ford_01.jpg',
#  'publishedAt': '2021-08-06T11:00:00Z',
#  'content': 'When my wife started a little garden in our urban backyard, all I could think about were the worms. Also the bugs, and the dirt, which is of course filled with worms and bugs and composted corn cobs.… [+3499 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
analyzer = SentimentIntensityAnalyzer()

btc_sentiments = []

for article in btc_all_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-08-06  When my wife started a little garden in our ur...   -0.3400
# 1  2021-07-19  Like Dogecoin devotees, the mayor of Reno, and...    0.6908
# 2  2021-08-10  Photo by Joe Raedle/Getty Images\r\n\n \n\n Tw...    0.4019
# 3  2021-08-12  By Joe TidyCyber reporter \r\n"Follow the mone...   -0.8860
# 4  2021-07-23  To get a roundup of TechCrunchs biggest and mo...    0.6240
#
#    positive  negative  neutral
# 0     0.000     0.061    0.939
# 1     0.178     0.000    0.822
# 2     0.080     0.000    0.920
# 3     0.000     0.271    0.729
# 4     0.127     0.000    0.873

# %%
# Create the Ethereum sentiment scores DataFrame

eth_sentiments = []

for article in eth_all_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-16  There are many blockchain platforms competing ...    0.3612
# 1  2021-07-29  Blockchain infrastructure startups are heating...   -0.2411
# 2  2021-08-05  Cent was founded in 2017 as an ad-free creator...    0.6956
# 3  2021-08-10  After the bell today, Coinbase reported anothe...    0.5719
# 4  2021-08-05  Representation of the Ethereum virtual currenc...    0.0000
#
#    positive  negative  neutral
# 0     0.075     0.000    0.925
# 1     0.000     0.061    0.939
# 2     0.190     0.000    0.810
# 3     0.139     0.000    0.861
# 4     0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.072564    0.050910    0.032820    0.916280
# std      0.346854    0.059581    0.049242    0.072273
# min     -0.886000    0.000000    0.000000    0.724000
# 25%     -0.058000    0.000000    0.000000    0.867750
# 50%      0.000000    0.046000    0.000000    0.921000
# 75%      0.345300    0.080500    0.069250    1.000000
# max      0.883400    0.274000    0.271000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.061328    0.047070    0.029270    0.923640
# std      0.368493    0.059251    0.049359    0.070373
# min     -0.757900    0.000000    0.000000    0.737000
# 25%     -0.063825    0.000000    0.000000    0.876750
# 50%      0.000000    0.000000    0.000000    0.926500
# 75%      0.345300    0.075500    0.061750    1.000000
# max      0.750600    0.201000    0.177000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!

# Create a list of stopwords
# YOUR CODE HERE!

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text

   
    # Create a tokenized list of the words
    
    
    # Lemmatize words into root words

   
    # Convert the words to lowercase
    
    
    # Remove the stop words
    
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---
